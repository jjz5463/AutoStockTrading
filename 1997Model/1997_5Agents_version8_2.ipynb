# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy - Modified: tech indicator
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# install finrl library
# !git clone https://github.com/AI4Finance-LLC/FinRL-Library.git

# %%
import sys
sys.path.append("FinRL-Library")

# %%
# install packages
# !pip install yfinance

# %%
# !pip install stockstats

# %%
#!pip install git+https://github.com/quantopian/pyfolio

# %%
# ## install finrl library
#!pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.apps import config
from finrl.finrl_meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.finrl_meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.finrl_meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.drl_agents.stablebaselines3.models_modified2 import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
# from config.py start_date is a string
# config.START_DATE

# %%
print(config.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
# I changed the end datae to yesterday, original date is 2021-07-06
df = YahooDownloader(start_date = '1997-01-01',
                     end_date = '2022-03-21',
                     ticker_list = config.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (179504, 8)

# %%
df.head()
# Out:
#          date       open       high        low      close       volume   tic  \
# 0  1997-01-02   0.188616   0.189732   0.185268   0.160551  143113600.0  AAPL
# 1  1997-01-02  13.656250  13.656250  13.375000  10.470350    6791200.0  AMGN
# 2  1997-01-02  16.338934  16.375404  15.645988  11.343322    5153433.0   AXP
# 3  1997-01-02  52.937500  52.937500  51.625000  32.312519    2786800.0    BA
# 4  1997-01-02  18.531250  18.531250  18.125000   9.498480    4976800.0   CAT
#
#    day
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3

# %%
df.tail()
# Out:
#               date        open        high         low       close  \
# 179499  2022-03-18  508.739990  510.679993  501.559998  506.119995
# 179500  2022-03-18  211.699997  219.259995  210.289993  219.110001
# 179501  2022-03-18   52.119999   52.290001   50.799999   50.799999
# 179502  2022-03-18   47.349998   47.450001   46.470001   47.360001
# 179503  2022-03-18  145.179993  145.570007  144.110001  145.440002
#
#             volume  tic  day
# 179499   5059000.0  UNH    4
# 179500  14608100.0    V    4
# 179501  70348600.0   VZ    4
# 179502  11368000.0  WBA    4
# 179503  10407600.0  WMT    4

# %%
df.shape
# Out:
# (179504, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close       volume   tic  \
# 0  1997-01-02   0.188616   0.189732   0.185268   0.160551  143113600.0  AAPL
# 1  1997-01-02  13.656250  13.656250  13.375000  10.470350    6791200.0  AMGN
# 2  1997-01-02  16.338934  16.375404  15.645988  11.343322    5153433.0   AXP
# 3  1997-01-02  52.937500  52.937500  51.625000  32.312519    2786800.0    BA
# 4  1997-01-02  18.531250  18.531250  18.125000   9.498480    4976800.0   CAT
#
#    day
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3

# %%
len(df.tic.unique())
# Out:
# 30

# %%
df.tic.value_counts()
# Out:
# AAPL    6346
# KO      6346
# WMT     6346
# WBA     6346
# VZ      6346
# UNH     6346
# TRV     6346
# PG      6346
# NKE     6346
# MSFT    6346
# MRK     6346
# MMM     6346
# AMGN    6346
# MCD     6346
# JPM     6346
# JNJ     6346
# INTC    6346
# IBM     6346
# HON     6346
# HD      6346
# DIS     6346
# CVX     6346
# CSCO    6346
# CAT     6346
# BA      6346
# AXP     6346
# GS      5758
# CRM     4467
# V       3526
# DOW      757
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
# added indicators
tech_indicators = [    "boll_ub", "boll_lb", # this two are new
'macd',
 'rsi_30',
 'cci_30',
 'dx_30']

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = tech_indicators,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.sample(5)
# Out:
#              date       open       high        low      close       volume  \
# 47850  2004-04-27  86.663483  87.944550  86.577438  52.429161    4987328.0
# 57400  2005-10-10  24.670000  24.680000  24.350000  17.539156   48880900.0
# 5564   1997-11-05   0.162946   0.166295   0.161272   0.140483  387116800.0
# 39494  2003-01-16   0.253750   0.263571   0.253750   0.223548  559070400.0
# 63742  2006-09-28  74.599998  74.989998  74.120003  48.714806    2736900.0
#
#         tic  day    boll_ub    boll_lb      macd     rsi_30      cci_30  \
# 47850   IBM    1  54.594203  51.773532 -0.434099  44.509025  -84.462860
# 57400  MSFT    0  19.140675  17.425517 -0.341468  36.892601 -139.512742
# 5564   AAPL    2   0.183756   0.110947 -0.008465  45.677609  -59.895543
# 39494  AAPL    3   0.230014   0.213888 -0.001571  47.568744  -39.367246
# 63742   MMM    3  49.254287  45.940053  0.573525  55.464327  122.403263
#
#            dx_30  turbulence
# 47850  34.263566   14.322433
# 57400  51.594518   25.942717
# 5564   21.194059    0.000000
# 39494   6.188274   17.070587
# 63742  26.934255    9.347572

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(tech_indicators)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 26, State Space: 209

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": tech_indicators,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)
train_start = '1997-01-01'
train_end = '2020-12-01' #original is 2020-4-1
val_test_start = '2020-12-01' #original is 2020-4-1
val_test_end = '2022-03-21'#original is 2021-7-06

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(train_start,train_end),
                 val_test_period=(val_test_start,val_test_end),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.01,
                    'learning_rate': 0.0005
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 64
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 100_000,
                      "learning_rate": 0.000005,
                      "batch_size": 64
                    }

TD3_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 100_000,
                      "learning_rate": 0.000005,
                      "batch_size": 64
                    }

SAC_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 100_000,
                      "learning_rate": 0.000005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 30_000, 
                 'ppo' : 100_000, 
                 'ddpg' : 10_000,
                  'td3' : 30_000,
                  'sac' : 80_000
                 }


timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000,
                  'td3' : 10_000,
                  'sac' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                  TD3_model_kwargs,
                                                  SAC_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  175.80273328172504
# ======Model training from:  1997-01-01 to  2020-12-02
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_126_30
# ------------------------------------
# | time/                 |          |
# |    fps                | 85       |
# |    iterations         | 100      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -37      |
# |    explained_variance | 0.0836   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 99       |
# |    policy_loss        | 12       |
# |    reward             | 0.063875 |
# |    std                | 1        |
# |    value_loss         | 1.1      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 200       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.0265   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 199       |
# |    policy_loss        | -228      |
# |    reward             | 1.2507877 |
# |    std                | 1.01      |
# |    value_loss         | 48.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 300        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 299        |
# |    policy_loss        | -10.8      |
# |    reward             | -1.3848976 |
# |    std                | 1.01       |
# |    value_loss         | 1.64       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 86       |
# |    iterations         | 400      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -37.1    |
# |    explained_variance | -0.202   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 399      |
# |    policy_loss        | -37.4    |
# |    reward             | 1.093796 |
# |    std                | 1.01     |
# |    value_loss         | 3.67     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 500        |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | -0.00554   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 499        |
# |    policy_loss        | -93.1      |
# |    reward             | -1.3248305 |
# |    std                | 1.01       |
# |    value_loss         | 9.29       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 86       |
# |    iterations         | 600      |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -37.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 599      |
# |    policy_loss        | 301      |
# |    reward             | 8.361987 |
# |    std                | 1.01     |
# |    value_loss         | 141      |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 700        |
# |    time_elapsed       | 40         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0.124      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 699        |
# |    policy_loss        | 38         |
# |    reward             | 0.71978885 |
# |    std                | 1.01       |
# |    value_loss         | 2.77       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 800       |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | 0.0314    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 799       |
# |    policy_loss        | -131      |
# |    reward             | 2.9219656 |
# |    std                | 1.01      |
# |    value_loss         | 15.3      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 900       |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | 0.0143    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 899       |
# |    policy_loss        | 205       |
# |    reward             | 7.2305007 |
# |    std                | 1.01      |
# |    value_loss         | 43        |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1000      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 999       |
# |    policy_loss        | -507      |
# |    reward             | -7.123615 |
# |    std                | 1.01      |
# |    value_loss         | 266       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1100      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | 0.0519    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1099      |
# |    policy_loss        | 469       |
# |    reward             | 20.531208 |
# |    std                | 1         |
# |    value_loss         | 204       |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 87          |
# |    iterations         | 1200        |
# |    time_elapsed       | 68          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -37         |
# |    explained_variance | 0.00526     |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1199        |
# |    policy_loss        | -643        |
# |    reward             | -0.14188555 |
# |    std                | 1           |
# |    value_loss         | 368         |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1300      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.353    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1299      |
# |    policy_loss        | 96.4      |
# |    reward             | 1.7567043 |
# |    std                | 1.01      |
# |    value_loss         | 8.32      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1400      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -1.07e-05 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1399      |
# |    policy_loss        | -246      |
# |    reward             | 1.5550951 |
# |    std                | 1.01      |
# |    value_loss         | 50.5      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1500       |
# |    time_elapsed       | 85         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1499       |
# |    policy_loss        | -59.7      |
# |    reward             | -1.5865306 |
# |    std                | 1.01       |
# |    value_loss         | 9.13       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1600       |
# |    time_elapsed       | 91         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0.00951    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1599       |
# |    policy_loss        | 213        |
# |    reward             | 0.52168685 |
# |    std                | 1.01       |
# |    value_loss         | 46.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1700       |
# |    time_elapsed       | 97         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1699       |
# |    policy_loss        | -29.3      |
# |    reward             | -2.9208405 |
# |    std                | 1.01       |
# |    value_loss         | 0.968      |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 86       |
# |    iterations         | 1800     |
# |    time_elapsed       | 103      |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -37.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1799     |
# |    policy_loss        | 98.5     |
# |    reward             | 3.188757 |
# |    std                | 1.01     |
# |    value_loss         | 33.5     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 86          |
# |    iterations         | 1900        |
# |    time_elapsed       | 109         |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -37.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1899        |
# |    policy_loss        | 85.7        |
# |    reward             | -0.10643855 |
# |    std                | 1.01        |
# |    value_loss         | 7.63        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 2000       |
# |    time_elapsed       | 115        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1999       |
# |    policy_loss        | 163        |
# |    reward             | -2.9897907 |
# |    std                | 1.01       |
# |    value_loss         | 22         |
# --------------------------------------
# ======A2C Validation from:  2020-12-02 to  2021-03-05
# A2C Sharpe Ratio:  0.16910458921859226
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_28
# -----------------------------------
# | time/              |            |
# |    fps             | 82         |
# |    iterations      | 1          |
# |    time_elapsed    | 24         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.94799286 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 2           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013462419 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.9       |
# |    explained_variance   | -0.0553     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.74        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0157     |
# |    reward               | -5.5144567  |
# |    std                  | 1           |
# |    value_loss           | 9.29        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 3           |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013513774 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37         |
# |    explained_variance   | 0.0092      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.91        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0166     |
# |    reward               | 0.030334743 |
# |    std                  | 1           |
# |    value_loss           | 32.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 4           |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015358198 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37         |
# |    explained_variance   | -0.00712    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 93.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0131     |
# |    reward               | 0.015567314 |
# |    std                  | 1.01        |
# |    value_loss           | 184         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 5           |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.021170039 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.1       |
# |    explained_variance   | 0.124       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.36        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0176     |
# |    reward               | -0.38318056 |
# |    std                  | 1.01        |
# |    value_loss           | 6.17        |
# -----------------------------------------
# ======PPO Validation from:  2020-12-02 to  2021-03-05
# PPO Sharpe Ratio:  0.05050178233202965
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_126_22
# day: 6019, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 9470192.78
# total_reward: 8470192.78
# total_cost: 5153.70
# total_trades: 68900
# Sharpe: 0.585
# =================================
# ======DDPG Validation from:  2020-12-02 to  2021-03-05
# ======TD3 Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/td3/td3_126_4
# ======TD3 Validation from:  2020-12-02 to  2021-03-05
# ======SAC Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/sac/sac_126_3
# ======SAC Validation from:  2020-12-02 to  2021-03-05
# ======Best Model Retraining from:  1997-01-01 to  2021-03-05
# ======Trading from:  2021-03-05 to  2021-06-04
# ============================================
# turbulence_threshold:  175.80273328172504
# ======Model training from:  1997-01-01 to  2021-03-05
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_189_23
# --------------------------------------
# | time/                 |            |
# |    fps                | 73         |
# |    iterations         | 100        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 99         |
# |    policy_loss        | 31.9       |
# |    reward             | -0.2523801 |
# |    std                | 1.01       |
# |    value_loss         | 1.81       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 72       |
# |    iterations         | 200      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -37.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 199      |
# |    policy_loss        | 128      |
# |    reward             | 5.812358 |
# |    std                | 1.01     |
# |    value_loss         | 18.5     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 300        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0.11       |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 299        |
# |    policy_loss        | 8.5        |
# |    reward             | -2.3457136 |
# |    std                | 1.01       |
# |    value_loss         | 1.2        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 400       |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.0908   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 399       |
# |    policy_loss        | -148      |
# |    reward             | 1.5460685 |
# |    std                | 1.01      |
# |    value_loss         | 17.1      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 72          |
# |    iterations         | 500         |
# |    time_elapsed       | 34          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -37.1       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 499         |
# |    policy_loss        | 114         |
# |    reward             | -0.22651751 |
# |    std                | 1.01        |
# |    value_loss         | 13.2        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 600        |
# |    time_elapsed       | 41         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 599        |
# |    policy_loss        | 329        |
# |    reward             | 0.84151167 |
# |    std                | 1.01       |
# |    value_loss         | 189        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 71         |
# |    iterations         | 700        |
# |    time_elapsed       | 48         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | -0.0102    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 699        |
# |    policy_loss        | 68.3       |
# |    reward             | -1.8370593 |
# |    std                | 1.01       |
# |    value_loss         | 9.37       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 800       |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.00176  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 799       |
# |    policy_loss        | -267      |
# |    reward             | 4.8629556 |
# |    std                | 1.01      |
# |    value_loss         | 63.8      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 900       |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 899       |
# |    policy_loss        | 105       |
# |    reward             | 2.3108535 |
# |    std                | 1.01      |
# |    value_loss         | 12.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 1000      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 999       |
# |    policy_loss        | -115      |
# |    reward             | -4.183332 |
# |    std                | 1.01      |
# |    value_loss         | 14.6      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 71       |
# |    iterations         | 1100     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -37.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1099     |
# |    policy_loss        | 401      |
# |    reward             | 12.88992 |
# |    std                | 1.01     |
# |    value_loss         | 255      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 1200      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1199      |
# |    policy_loss        | -347      |
# |    reward             | 12.300703 |
# |    std                | 1.01      |
# |    value_loss         | 105       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 1300       |
# |    time_elapsed       | 90         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | -0.0662    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1299       |
# |    policy_loss        | 37         |
# |    reward             | -3.3372934 |
# |    std                | 1.01       |
# |    value_loss         | 2.87       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 1400       |
# |    time_elapsed       | 96         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1399       |
# |    policy_loss        | -58        |
# |    reward             | -3.1159272 |
# |    std                | 1.01       |
# |    value_loss         | 19.7       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 1500       |
# |    time_elapsed       | 103        |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1499       |
# |    policy_loss        | 374        |
# |    reward             | 0.97693807 |
# |    std                | 1.01       |
# |    value_loss         | 108        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 1600      |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1599      |
# |    policy_loss        | -16.8     |
# |    reward             | 2.1016874 |
# |    std                | 1.01      |
# |    value_loss         | 6.75      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 1700      |
# |    time_elapsed       | 117       |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1699      |
# |    policy_loss        | 66.4      |
# |    reward             | 3.4183187 |
# |    std                | 1.01      |
# |    value_loss         | 4.77      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 1800      |
# |    time_elapsed       | 124       |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1799      |
# |    policy_loss        | 200       |
# |    reward             | 1.6529938 |
# |    std                | 1.01      |
# |    value_loss         | 39.4      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 1900       |
# |    time_elapsed       | 131        |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1899       |
# |    policy_loss        | 72.3       |
# |    reward             | 0.91323084 |
# |    std                | 1.01       |
# |    value_loss         | 11.5       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 72          |
# |    iterations         | 2000        |
# |    time_elapsed       | 137         |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -37.1       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1999        |
# |    policy_loss        | 10.8        |
# |    reward             | -0.25132868 |
# |    std                | 1.01        |
# |    value_loss         | 2.78        |
# ---------------------------------------
# ======A2C Validation from:  2021-03-05 to  2021-06-04
# A2C Sharpe Ratio:  0.32150453631365244
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_23
# ---------------------------------
# | time/              |          |
# |    fps             | 74       |
# |    iterations      | 1        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 2048     |
# | train/             |          |
# |    reward          | 0.681919 |
# ---------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 74           |
# |    iterations           | 2            |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0137360925 |
# |    clip_fraction        | 0.2          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -37          |
# |    explained_variance   | 0.0258       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.75         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.015       |
# |    reward               | -4.558692    |
# |    std                  | 1.01         |
# |    value_loss           | 6.86         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 3           |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013581654 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37         |
# |    explained_variance   | 0.0181      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.013      |
# |    reward               | 0.1828953   |
# |    std                  | 1.01        |
# |    value_loss           | 18.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 4           |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012964237 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.1       |
# |    explained_variance   | -0.00102    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 111         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0123     |
# |    reward               | -0.52964956 |
# |    std                  | 1.01        |
# |    value_loss           | 233         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 5          |
# |    time_elapsed         | 139        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.02718871 |
# |    clip_fraction        | 0.272      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -37.1      |
# |    explained_variance   | 0.171      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 5.94       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0211    |
# |    reward               | 2.1948147  |
# |    std                  | 1.01       |
# |    value_loss           | 10.1       |
# ----------------------------------------
# ======PPO Validation from:  2021-03-05 to  2021-06-04
# PPO Sharpe Ratio:  0.31048404605992425
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_189_22
# day: 6082, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 10508045.24
# total_reward: 9508045.24
# total_cost: 5078.96
# total_trades: 74478
# Sharpe: 0.558
# =================================
# ======DDPG Validation from:  2021-03-05 to  2021-06-04
# ======TD3 Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/td3/td3_189_4
# ======TD3 Validation from:  2021-03-05 to  2021-06-04
# ======SAC Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/sac/sac_189_3
# ======SAC Validation from:  2021-03-05 to  2021-06-04
# ======Best Model Retraining from:  1997-01-01 to  2021-06-04
# ======Trading from:  2021-06-04 to  2021-09-02
# ============================================
# turbulence_threshold:  175.80273328172504
# ======Model training from:  1997-01-01 to  2021-06-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_252_22
# --------------------------------------
# | time/                 |            |
# |    fps                | 74         |
# |    iterations         | 100        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | -0.85      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 99         |
# |    policy_loss        | 2.24       |
# |    reward             | 0.32961437 |
# |    std                | 1.01       |
# |    value_loss         | 0.676      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 74        |
# |    iterations         | 200       |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.112    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 199       |
# |    policy_loss        | 7.08      |
# |    reward             | 3.5643594 |
# |    std                | 1.01      |
# |    value_loss         | 2.95      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 75          |
# |    iterations         | 300         |
# |    time_elapsed       | 19          |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -37.1       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 299         |
# |    policy_loss        | -42.5       |
# |    reward             | -0.19774601 |
# |    std                | 1.01        |
# |    value_loss         | 2.91        |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 76           |
# |    iterations         | 400          |
# |    time_elapsed       | 26           |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -37.2        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0005       |
# |    n_updates          | 399          |
# |    policy_loss        | -32.8        |
# |    reward             | 0.0151466755 |
# |    std                | 1.01         |
# |    value_loss         | 1.79         |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 76         |
# |    iterations         | 500        |
# |    time_elapsed       | 32         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 499        |
# |    policy_loss        | -10.6      |
# |    reward             | -1.3682817 |
# |    std                | 1.01       |
# |    value_loss         | 1.5        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 76       |
# |    iterations         | 600      |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -37.2    |
# |    explained_variance | -0.0182  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 599      |
# |    policy_loss        | 147      |
# |    reward             | 4.835582 |
# |    std                | 1.01     |
# |    value_loss         | 40.1     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 76          |
# |    iterations         | 700         |
# |    time_elapsed       | 45          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -37.2       |
# |    explained_variance | 0.000312    |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 699         |
# |    policy_loss        | 63          |
# |    reward             | -0.75751066 |
# |    std                | 1.01        |
# |    value_loss         | 5.25        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 77        |
# |    iterations         | 800       |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | 0.00662   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 799       |
# |    policy_loss        | -114      |
# |    reward             | 2.2444441 |
# |    std                | 1.01      |
# |    value_loss         | 11.6      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 77       |
# |    iterations         | 900      |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -37.2    |
# |    explained_variance | -0.0416  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 899      |
# |    policy_loss        | 131      |
# |    reward             | 5.646209 |
# |    std                | 1.01     |
# |    value_loss         | 17.2     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 77         |
# |    iterations         | 1000       |
# |    time_elapsed       | 64         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 999        |
# |    policy_loss        | -317       |
# |    reward             | -1.6854688 |
# |    std                | 1.01       |
# |    value_loss         | 104        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 77       |
# |    iterations         | 1100     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -37.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1099     |
# |    policy_loss        | 445      |
# |    reward             | 19.42583 |
# |    std                | 1.01     |
# |    value_loss         | 172      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 77        |
# |    iterations         | 1200      |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1199      |
# |    policy_loss        | -827      |
# |    reward             | 12.732106 |
# |    std                | 1.01      |
# |    value_loss         | 623       |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 77          |
# |    iterations         | 1300        |
# |    time_elapsed       | 84          |
# |    total_timesteps    | 6500        |
# | train/                |             |
# |    entropy_loss       | -37.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1299        |
# |    policy_loss        | 7.19        |
# |    reward             | -0.22473015 |
# |    std                | 1.01        |
# |    value_loss         | 0.175       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 77         |
# |    iterations         | 1400       |
# |    time_elapsed       | 90         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -37.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1399       |
# |    policy_loss        | 238        |
# |    reward             | -3.3855062 |
# |    std                | 1.02       |
# |    value_loss         | 44.4       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 77         |
# |    iterations         | 1500       |
# |    time_elapsed       | 96         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -37.3      |
# |    explained_variance | 0.00315    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1499       |
# |    policy_loss        | 207        |
# |    reward             | 0.39341342 |
# |    std                | 1.02       |
# |    value_loss         | 41.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 77         |
# |    iterations         | 1600       |
# |    time_elapsed       | 103        |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -37.3      |
# |    explained_variance | -0.152     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1599       |
# |    policy_loss        | -125       |
# |    reward             | -0.9736756 |
# |    std                | 1.02       |
# |    value_loss         | 13.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 77        |
# |    iterations         | 1700      |
# |    time_elapsed       | 109       |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1699      |
# |    policy_loss        | -3.95     |
# |    reward             | -2.469782 |
# |    std                | 1.02      |
# |    value_loss         | 0.505     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 78        |
# |    iterations         | 1800      |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | -0.0947   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1799      |
# |    policy_loss        | 109       |
# |    reward             | -3.724493 |
# |    std                | 1.02      |
# |    value_loss         | 21.9      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 78        |
# |    iterations         | 1900      |
# |    time_elapsed       | 121       |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1899      |
# |    policy_loss        | 31.2      |
# |    reward             | 2.6852205 |
# |    std                | 1.02      |
# |    value_loss         | 2.23      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 78        |
# |    iterations         | 2000      |
# |    time_elapsed       | 127       |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1999      |
# |    policy_loss        | 102       |
# |    reward             | 2.1047623 |
# |    std                | 1.02      |
# |    value_loss         | 11.2      |
# -------------------------------------
# ======A2C Validation from:  2021-06-04 to  2021-09-02
# A2C Sharpe Ratio:  -0.03916854030106828
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# ...
# |    iterations         | 300        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 299        |
# |    policy_loss        | -95.8      |
# |    reward             | -1.3071901 |
# |    std                | 1          |
# |    value_loss         | 12.8       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 400       |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 399       |
# |    policy_loss        | -53.3     |
# |    reward             | 1.2507001 |
# |    std                | 1.01      |
# |    value_loss         | 3.95      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 71         |
# |    iterations         | 500        |
# |    time_elapsed       | 35         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | 0.0517     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 499        |
# |    policy_loss        | -63        |
# |    reward             | -0.7487883 |
# |    std                | 1.01       |
# |    value_loss         | 7.87       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 600       |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 599       |
# |    policy_loss        | 345       |
# |    reward             | 4.8429227 |
# |    std                | 1.01      |
# |    value_loss         | 115       |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 71           |
# |    iterations         | 700          |
# |    time_elapsed       | 48           |
# |    total_timesteps    | 3500         |
# | train/                |              |
# |    entropy_loss       | -37.1        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0005       |
# |    n_updates          | 699          |
# |    policy_loss        | 145          |
# |    reward             | -0.059756584 |
# |    std                | 1.01         |
# |    value_loss         | 16.7         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 800       |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 799       |
# |    policy_loss        | -444      |
# |    reward             | 5.6495404 |
# |    std                | 1.01      |
# |    value_loss         | 163       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 900       |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 899       |
# |    policy_loss        | 89.4      |
# |    reward             | 3.2870407 |
# |    std                | 1.01      |
# |    value_loss         | 11.8      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 1000      |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.0862   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 999       |
# |    policy_loss        | -147      |
# |    reward             | 0.6751642 |
# |    std                | 1.01      |
# |    value_loss         | 26.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 1100      |
# |    time_elapsed       | 75        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1099      |
# |    policy_loss        | 638       |
# |    reward             | 11.515015 |
# |    std                | 1         |
# |    value_loss         | 372       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 1200      |
# |    time_elapsed       | 82        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1199      |
# |    policy_loss        | -631      |
# |    reward             | 18.895428 |
# |    std                | 1.01      |
# |    value_loss         | 435       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 73         |
# |    iterations         | 1300       |
# |    time_elapsed       | 89         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | -0.281     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1299       |
# |    policy_loss        | 19.5       |
# |    reward             | 0.11244648 |
# |    std                | 1.01       |
# |    value_loss         | 0.691      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 73        |
# |    iterations         | 1400      |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | -0.0849   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1399      |
# |    policy_loss        | -204      |
# |    reward             | 1.7594818 |
# |    std                | 1.01      |
# |    value_loss         | 41.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 73         |
# |    iterations         | 1500       |
# |    time_elapsed       | 102        |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1499       |
# |    policy_loss        | 50         |
# |    reward             | -2.2926571 |
# |    std                | 1.01       |
# |    value_loss         | 2.77       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 73        |
# |    iterations         | 1600      |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1599      |
# |    policy_loss        | 50.6      |
# |    reward             | 1.1050688 |
# |    std                | 1.01      |
# |    value_loss         | 2.57      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 73         |
# |    iterations         | 1700       |
# |    time_elapsed       | 115        |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0.0178     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1699       |
# |    policy_loss        | -13.2      |
# |    reward             | 0.49380088 |
# |    std                | 1.01       |
# |    value_loss         | 0.251      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 73          |
# |    iterations         | 1800        |
# |    time_elapsed       | 121         |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -37.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1799        |
# |    policy_loss        | -15.8       |
# |    reward             | -0.10962828 |
# |    std                | 1.01        |
# |    value_loss         | 1.12        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 74        |
# |    iterations         | 1900      |
# |    time_elapsed       | 128       |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | 0.0469    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1899      |
# |    policy_loss        | -94.7     |
# |    reward             | 0.6202625 |
# |    std                | 1.01      |
# |    value_loss         | 9.68      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 74        |
# |    iterations         | 2000      |
# |    time_elapsed       | 134       |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | -0.297    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1999      |
# |    policy_loss        | 39.7      |
# |    reward             | 0.5315983 |
# |    std                | 1.01      |
# |    value_loss         | 1.05      |
# -------------------------------------
# ======A2C Validation from:  2021-09-02 to  2021-12-02
# A2C Sharpe Ratio:  -0.2891938508107831
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_315_20
# ----------------------------------
# | time/              |           |
# |    fps             | 78        |
# |    iterations      | 1         |
# |    time_elapsed    | 25        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 0.8945708 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 2           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012940971 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.9       |
# |    explained_variance   | -0.00684    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.15        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0103     |
# |    reward               | -4.7844434  |
# |    std                  | 1           |
# |    value_loss           | 8.41        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 3           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010899352 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37         |
# |    explained_variance   | -0.00289    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 16.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0163     |
# |    reward               | 0.40470883  |
# |    std                  | 1.01        |
# |    value_loss           | 33.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 4           |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013476405 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.1       |
# |    explained_variance   | -0.00302    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 354         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0117     |
# |    reward               | 0.3996836   |
# |    std                  | 1.01        |
# |    value_loss           | 472         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 5           |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.017854452 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.1       |
# |    explained_variance   | 0.00699     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0178     |
# |    reward               | 2.9867005   |
# |    std                  | 1.01        |
# |    value_loss           | 21.2        |
# -----------------------------------------
# ======PPO Validation from:  2021-09-02 to  2021-12-02
# PPO Sharpe Ratio:  -0.140300577140265
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_315_18
# day: 6208, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 13628128.46
# total_reward: 12628128.46
# total_cost: 3567.26
# total_trades: 93263
# Sharpe: 0.629
# =================================
# ======DDPG Validation from:  2021-09-02 to  2021-12-02
# ======TD3 Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/td3/td3_315_4
# ======TD3 Validation from:  2021-09-02 to  2021-12-02
# ======SAC Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/sac/sac_315_3
# ======SAC Validation from:  2021-09-02 to  2021-12-02
# ======Best Model Retraining from:  1997-01-01 to  2021-12-02
# ======Trading from:  2021-12-02 to  2022-03-04
# Ensemble Strategy took:  71.47625351746878  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe  \
# 0  126  2020-12-02  2021-03-05        A2C   0.169105   0.050502    -0.05196
# 1  189  2021-03-05  2021-06-04        SAC   0.321505   0.310484    0.138581
# 2  252  2021-06-04  2021-09-02       DDPG  -0.039169    0.07905    0.239777
# 3  315  2021-09-02  2021-12-02       DDPG  -0.289194  -0.140301   -0.055699
#
#   TD3 Sharpe SAC Sharpe
# 0   0.157886  -0.047289
# 1   0.253944   0.520326
# 2   0.074892  -0.057538
# 3  -0.106751  -0.070002

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > val_test_start)&(processed.date <= val_test_end)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  0.5679601519109712

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2021-03-05           NaN  2021-03-05
# 1   1.001835e+06  2021-03-08      0.001835  2021-03-08
# 2   1.002280e+06  2021-03-09      0.000444  2021-03-09
# 3   1.006420e+06  2021-03-10      0.004131  2021-03-10
# 4   1.008363e+06  2021-03-11      0.001931  2021-03-11

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.065986
# Cumulative returns     0.065986
# Annual volatility      0.127142
# Sharpe ratio           0.567960
# Calmar ratio           0.689967
# Stability              0.464592
# Max drawdown          -0.095636
# Omega ratio            1.098030
# Sortino ratio          0.816150
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.868190
# Daily value at risk   -0.015732
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.076357
# Cumulative returns     0.076042
# Annual volatility      0.128444
# Sharpe ratio           0.639265
# Calmar ratio           0.766080
# Stability              0.396026
# Max drawdown          -0.099672
# Omega ratio            1.110797
# Sortino ratio          0.907534
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.952372
# Daily value at risk   -0.015857
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-03-05</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-03-03</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>6.599%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>6.599%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>12.714%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.57</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.69</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.46</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-9.564%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.10</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.82</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.87</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.573%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.82</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>9.56</td>
#       <td>2021-12-29</td>
#       <td>2022-02-24</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>7.09</td>
#       <td>2021-08-16</td>
#       <td>2021-10-04</td>
#       <td>2021-10-26</td>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6.19</td>
#       <td>2021-05-07</td>
#       <td>2021-06-18</td>
#       <td>2021-08-11</td>
#       <td>69</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.74</td>
#       <td>2021-11-03</td>
#       <td>2021-11-30</td>
#       <td>2021-12-07</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.02</td>
#       <td>2021-04-16</td>
#       <td>2021-04-28</td>
#       <td>2021-05-07</td>
#       <td>16</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.03%</td>
#       <td>-2.43%</td>
#       <td>3.07%</td>
#     </tr>
#   </tbody>
# </table>
