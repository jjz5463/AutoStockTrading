# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy - Modified: tech indicator
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# install finrl library
# !git clone https://github.com/AI4Finance-LLC/FinRL-Library.git

# %%
import sys
sys.path.append("FinRL-Library")

# %%
# install packages
#!pip install yfinance

# %%
# !pip install stockstats
# Out:
# Requirement already satisfied: stockstats in /opt/anaconda3/lib/python3.8/site-packages (0.4.1)
# Requirement already satisfied: pandas>=0.24.2 in /opt/anaconda3/lib/python3.8/site-packages (from stockstats) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.2->stockstats) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.2->stockstats) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.2->stockstats) (2.8.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.2->stockstats) (1.16.0)

# %%
#!pip install git+https://github.com/quantopian/pyfolio

# %%
# ## install finrl library
#!pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.apps import config
from finrl.finrl_meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.finrl_meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.finrl_meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.drl_agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
# from config.py start_date is a string
config.START_DATE
# Out:
# '2009-01-01'

# %%
print(config.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
# I changed the end datae to yesterday, original date is 2021-07-06
df = YahooDownloader(start_date = '2006-01-01',
                     end_date = '2022-03-21',
                     ticker_list = config.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (118551, 8)

# %%
df.head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2006-01-03   2.585000   2.669643   2.580357   2.285945  807234400  AAPL
# 1  2006-01-03  79.360001  81.239998  78.099998  61.612621    9114400  AMGN
# 2  2006-01-03  51.700001  52.580002  51.049999  40.843647    7825700   AXP
# 3  2006-01-03  70.400002  70.599998  69.330002  50.119694    4943000    BA
# 4  2006-01-03  57.869999  58.110001  57.049999  37.493553    3697500   CAT
#
#    day
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
df.tail()
# Out:
#               date        open        high         low       close    volume  \
# 118546  2022-03-18  508.739990  510.679993  501.559998  506.119995   5059000
# 118547  2022-03-18  211.699997  219.259995  210.289993  219.110001  14608100
# 118548  2022-03-18   52.119999   52.290001   50.799999   50.799999  70348600
# 118549  2022-03-18   47.349998   47.450001   46.470001   47.360001  11368000
# 118550  2022-03-18  145.179993  145.570007  144.110001  145.440002  10407600
#
#         tic  day
# 118546  UNH    4
# 118547    V    4
# 118548   VZ    4
# 118549  WBA    4
# 118550  WMT    4

# %%
df.shape
# Out:
# (118551, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2006-01-03   2.585000   2.669643   2.580357   2.285945  807234400  AAPL
# 1  2006-01-03  79.360001  81.239998  78.099998  61.612621    9114400  AMGN
# 2  2006-01-03  51.700001  52.580002  51.049999  40.843647    7825700   AXP
# 3  2006-01-03  70.400002  70.599998  69.330002  50.119694    4943000    BA
# 4  2006-01-03  57.869999  58.110001  57.049999  37.493553    3697500   CAT
#
#    day
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
len(df.tic.unique())
# Out:
# 30

# %%
df.tic.value_counts()
# Out:
# AAPL    4081
# AMGN    4081
# WMT     4081
# WBA     4081
# VZ      4081
# UNH     4081
# TRV     4081
# PG      4081
# NKE     4081
# MSFT    4081
# MRK     4081
# MMM     4081
# MCD     4081
# KO      4081
# JPM     4081
# JNJ     4081
# INTC    4081
# IBM     4081
# HON     4081
# HD      4081
# GS      4081
# DIS     4081
# CVX     4081
# CSCO    4081
# CRM     4081
# CAT     4081
# BA      4081
# AXP     4081
# V       3526
# DOW      757
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
# added indicators
tech_indicators = [    #"boll_ub", "boll_lb", # this two are new
'macd',
 'rsi_30',
 'cci_30',
 'dx_30']

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = tech_indicators,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.sample(5)
# Out:
#              date        open        high         low       close    volume  \
# 49589  2013-01-16   85.029999   85.339996   84.269997   66.577766   7753800
# 89438  2018-09-11   46.910000   47.169998   46.439999   42.131516  17291500
# 63729  2015-01-20  159.210007  159.729996  154.649994  129.198837   3664400
# 16733  2008-05-19   60.759998   60.869999   60.400002   40.232208   4924600
# 16783  2008-05-21   58.775230   59.194714   57.211704   41.092129   4041350
#
#         tic  day      macd     rsi_30      cci_30      dx_30  turbulence
# 49589  AMGN    2 -0.368223  43.960825 -200.472094  34.054654   56.149577
# 89438  CSCO    1  0.821573  61.605227   62.714316  15.183362   31.650704
# 63729  AMGN    1 -1.420099  50.482659  -64.259420   2.593140   56.210568
# 16733   MCD    0  0.605194  58.297279   72.316422  14.778011   18.918982
# 16783   HON    2  0.555876  52.907030   58.210504  11.699276   18.133861

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(tech_indicators)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 28, State Space: 169

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": tech_indicators,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)
train_start = '2006-01-01'
train_end = '2020-12-01' #original is 2020-4-1
val_test_start = '2020-12-01' #original is 2020-4-1
val_test_end = '2022-03-21'#original is 2021-7-06

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(train_start,train_end),
                 val_test_period=(val_test_start,val_test_end),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.01,
                    'learning_rate': 0.0005
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 64
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 100_000,
                      "learning_rate": 0.000005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 30_000, 
                 'ppo' : 100_000, 
                 'ddpg' : 10_000
                 }


timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  202.91028385393966
# ======Model training from:  2006-01-01 to  2020-12-02
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_126_31
# -------------------------------------
# | time/                 |           |
# |    fps                | 46        |
# |    iterations         | 100       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -39.7     |
# |    explained_variance | 0.0373    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 99        |
# |    policy_loss        | -48.1     |
# |    reward             | 0.1639865 |
# |    std                | 0.999     |
# |    value_loss         | 3.9       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 65         |
# |    iterations         | 200        |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | 0.0239     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 199        |
# |    policy_loss        | 47.4       |
# |    reward             | 0.38206667 |
# |    std                | 0.999      |
# |    value_loss         | 2.7        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 75         |
# |    iterations         | 300        |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | 0.0197     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 299        |
# |    policy_loss        | -52.5      |
# |    reward             | 0.39748862 |
# |    std                | 0.999      |
# |    value_loss         | 2.27       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 400        |
# |    time_elapsed       | 24         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | 0.0344     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 399        |
# |    policy_loss        | -57        |
# |    reward             | -0.7517668 |
# |    std                | 0.999      |
# |    value_loss         | 2.41       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 500        |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | -0.0208    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 499        |
# |    policy_loss        | 4.72       |
# |    reward             | -2.4682755 |
# |    std                | 1          |
# |    value_loss         | 3.12       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 90         |
# |    iterations         | 600        |
# |    time_elapsed       | 33         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | 0.132      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 599        |
# |    policy_loss        | 11.7       |
# |    reward             | 0.54133296 |
# |    std                | 1          |
# |    value_loss         | 0.656      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 92          |
# |    iterations         | 700         |
# |    time_elapsed       | 37          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -39.7       |
# |    explained_variance | 0.0201      |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 699         |
# |    policy_loss        | 43          |
# |    reward             | 0.037405666 |
# |    std                | 1           |
# |    value_loss         | 3.88        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 94          |
# |    iterations         | 800         |
# |    time_elapsed       | 42          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | -2.66       |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 799         |
# |    policy_loss        | 11.8        |
# |    reward             | -0.33708766 |
# |    std                | 1           |
# |    value_loss         | 0.187       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 95          |
# |    iterations         | 900         |
# |    time_elapsed       | 46          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | 0.115       |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 899         |
# |    policy_loss        | 50.8        |
# |    reward             | -0.64867884 |
# |    std                | 1           |
# |    value_loss         | 4.6         |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 97        |
# |    iterations         | 1000      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -39.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 999       |
# |    policy_loss        | 56.1      |
# |    reward             | 0.8295756 |
# |    std                | 1         |
# |    value_loss         | 4.1       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 98        |
# |    iterations         | 1100      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -39.8     |
# |    explained_variance | -0.295    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1099      |
# |    policy_loss        | 55.3      |
# |    reward             | 0.7043724 |
# |    std                | 1         |
# |    value_loss         | 2.69      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 99          |
# |    iterations         | 1200        |
# |    time_elapsed       | 60          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | -0.188      |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1199        |
# |    policy_loss        | 151         |
# |    reward             | -0.39810172 |
# |    std                | 1           |
# |    value_loss         | 15.4        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 100         |
# |    iterations         | 1300        |
# |    time_elapsed       | 64          |
# |    total_timesteps    | 6500        |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | -0.0966     |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1299        |
# |    policy_loss        | -87.7       |
# |    reward             | -0.11985892 |
# |    std                | 1           |
# |    value_loss         | 5.96        |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 101           |
# |    iterations         | 1400          |
# |    time_elapsed       | 69            |
# |    total_timesteps    | 7000          |
# | train/                |               |
# |    entropy_loss       | -39.8         |
# |    explained_variance | -0.0121       |
# |    learning_rate      | 0.0005        |
# |    n_updates          | 1399          |
# |    policy_loss        | -643          |
# |    reward             | -0.0021708163 |
# |    std                | 1             |
# |    value_loss         | 340           |
# -----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 1500      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -39.8     |
# |    explained_variance | 0.0333    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1499      |
# |    policy_loss        | 1.31e+03  |
# |    reward             | 5.9336987 |
# |    std                | 1         |
# |    value_loss         | 1.19e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 102       |
# |    iterations         | 1600      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1599      |
# |    policy_loss        | 27.3      |
# |    reward             | 0.6906018 |
# |    std                | 1         |
# |    value_loss         | 0.519     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 102        |
# |    iterations         | 1700       |
# |    time_elapsed       | 82         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | 0.00247    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1699       |
# |    policy_loss        | 9.56       |
# |    reward             | -1.6641667 |
# |    std                | 1.01       |
# |    value_loss         | 0.275      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 103       |
# |    iterations         | 1800      |
# |    time_elapsed       | 87        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1799      |
# |    policy_loss        | -138      |
# |    reward             | -0.505705 |
# |    std                | 1.01      |
# |    value_loss         | 12.2      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 103        |
# |    iterations         | 1900       |
# |    time_elapsed       | 91         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | -0.119     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1899       |
# |    policy_loss        | -56.9      |
# |    reward             | 0.17692716 |
# |    std                | 1          |
# |    value_loss         | 2.65       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 103         |
# |    iterations         | 2000        |
# |    time_elapsed       | 96          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1999        |
# |    policy_loss        | -57.8       |
# |    reward             | -0.61516094 |
# |    std                | 1           |
# |    value_loss         | 9.67        |
# ---------------------------------------
# ======A2C Validation from:  2020-12-02 to  2021-03-05
# A2C Sharpe Ratio:  0.0030883941993261077
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_29
# -----------------------------------
# | time/              |            |
# |    fps             | 112        |
# |    iterations      | 1          |
# |    time_elapsed    | 18         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.83783287 |
# -----------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 107        |
# |    iterations           | 2          |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01859781 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -39.7      |
# |    explained_variance   | 0.0202     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 3.25       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0296    |
# |    reward               | 0.17336462 |
# |    std                  | 1          |
# |    value_loss           | 7.64       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 3           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.019501306 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.8       |
# |    explained_variance   | -0.0205     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.55        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0222     |
# |    reward               | 1.3823372   |
# |    std                  | 1           |
# |    value_loss           | 32.1        |
# -----------------------------------------
# day: 3754, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 3072624.76
# total_reward: 2072624.76
# total_cost: 396680.81
# total_trades: 100623
# Sharpe: 0.468
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 4           |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.019399252 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.8       |
# |    explained_variance   | -0.0711     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.49        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0196     |
# |    reward               | 3.5304565   |
# |    std                  | 1.01        |
# |    value_loss           | 9.7         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 107        |
# |    iterations           | 5          |
# |    time_elapsed         | 95         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.02255574 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -39.9      |
# |    explained_variance   | -0.00149   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 36.5       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0226    |
# |    reward               | -0.7238582 |
# |    std                  | 1.01       |
# |    value_loss           | 53.7       |
# ----------------------------------------
# ======PPO Validation from:  2020-12-02 to  2021-03-05
# PPO Sharpe Ratio:  0.1034424181209691
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_126_23
# ======DDPG Validation from:  2020-12-02 to  2021-03-05
# ======Best Model Retraining from:  2006-01-01 to  2021-03-05
# ======Trading from:  2021-03-05 to  2021-06-04
# ============================================
# turbulence_threshold:  202.91028385393966
# ======Model training from:  2006-01-01 to  2021-03-05
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_189_22
# --------------------------------------
# | time/                 |            |
# |    fps                | 92         |
# |    iterations         | 100        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | -0.559     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 99         |
# |    policy_loss        | -56.7      |
# |    reward             | 0.33267516 |
# |    std                | 1          |
# |    value_loss         | 5.15       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 200        |
# |    time_elapsed       | 10         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | -0.261     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 199        |
# |    policy_loss        | 40.6       |
# |    reward             | 0.47410065 |
# |    std                | 1          |
# |    value_loss         | 2.75       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 95        |
# |    iterations         | 300       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -39.8     |
# |    explained_variance | 0.464     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 299       |
# |    policy_loss        | -151      |
# |    reward             | 0.6404324 |
# |    std                | 1         |
# |    value_loss         | 13.3      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 96          |
# |    iterations         | 400         |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | -2.02       |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 399         |
# |    policy_loss        | -35.4       |
# |    reward             | -0.44205162 |
# |    std                | 1           |
# |    value_loss         | 1.51        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 96         |
# |    iterations         | 500        |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 499        |
# |    policy_loss        | -43.2      |
# |    reward             | -3.3827608 |
# |    std                | 1          |
# |    value_loss         | 6.85       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 97        |
# |    iterations         | 600       |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -39.8     |
# |    explained_variance | 0.11      |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 599       |
# |    policy_loss        | -13.7     |
# |    reward             | 1.0178478 |
# |    std                | 1         |
# |    value_loss         | 0.277     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 97          |
# |    iterations         | 700         |
# |    time_elapsed       | 36          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | 0.000931    |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 699         |
# |    policy_loss        | -122        |
# |    reward             | -0.55618846 |
# |    std                | 1           |
# |    value_loss         | 36.4        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 98          |
# |    iterations         | 800         |
# |    time_elapsed       | 40          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -39.9       |
# |    explained_variance | -0.312      |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 799         |
# |    policy_loss        | 55.2        |
# |    reward             | -0.46568054 |
# |    std                | 1.01        |
# |    value_loss         | 3.56        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 98        |
# |    iterations         | 900       |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | 0.0407    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 899       |
# |    policy_loss        | 62.4      |
# |    reward             | 4.6316624 |
# |    std                | 1.01      |
# |    value_loss         | 4.44      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 99          |
# |    iterations         | 1000        |
# |    time_elapsed       | 50          |
# |    total_timesteps    | 5000        |
# | train/                |             |
# |    entropy_loss       | -39.9       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 999         |
# |    policy_loss        | 82          |
# |    reward             | -0.32534075 |
# |    std                | 1.01        |
# |    value_loss         | 12.9        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 1100      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | -0.722    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1099      |
# |    policy_loss        | -7.84     |
# |    reward             | 3.1635795 |
# |    std                | 1.01      |
# |    value_loss         | 0.493     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 1200      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1199      |
# |    policy_loss        | 149       |
# |    reward             | 0.4855788 |
# |    std                | 1.01      |
# |    value_loss         | 14.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 1300      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | 0.402     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1299      |
# |    policy_loss        | -15.3     |
# |    reward             | 1.6470377 |
# |    std                | 1.01      |
# |    value_loss         | 0.286     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 101        |
# |    iterations         | 1400       |
# |    time_elapsed       | 68         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | -0.129     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1399       |
# |    policy_loss        | 175        |
# |    reward             | -1.8589702 |
# |    std                | 1.01       |
# |    value_loss         | 25.5       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 102        |
# |    iterations         | 1500       |
# |    time_elapsed       | 73         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | 0.0235     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1499       |
# |    policy_loss        | 503        |
# |    reward             | -2.2134323 |
# |    std                | 1.01       |
# |    value_loss         | 168        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 102       |
# |    iterations         | 1600      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | -0.0142   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1599      |
# |    policy_loss        | -47.4     |
# |    reward             | 0.7127766 |
# |    std                | 1.01      |
# |    value_loss         | 2.32      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 102         |
# |    iterations         | 1700        |
# |    time_elapsed       | 82          |
# |    total_timesteps    | 8500        |
# | train/                |             |
# |    entropy_loss       | -39.9       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1699        |
# |    policy_loss        | 54.8        |
# |    reward             | -0.39236113 |
# |    std                | 1.01        |
# |    value_loss         | 3.54        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 102         |
# |    iterations         | 1800        |
# |    time_elapsed       | 87          |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -39.9       |
# |    explained_variance | 0.253       |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1799        |
# |    policy_loss        | -28.1       |
# |    reward             | -0.76481193 |
# |    std                | 1.01        |
# |    value_loss         | 0.684       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 102       |
# |    iterations         | 1900      |
# |    time_elapsed       | 92        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1899      |
# |    policy_loss        | -25.6     |
# |    reward             | -3.476828 |
# |    std                | 1.01      |
# |    value_loss         | 0.722     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 103       |
# |    iterations         | 2000      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1999      |
# |    policy_loss        | 166       |
# |    reward             | 1.3268455 |
# |    std                | 1.01      |
# |    value_loss         | 21        |
# -------------------------------------
# ======A2C Validation from:  2021-03-05 to  2021-06-04
# A2C Sharpe Ratio:  0.3257966206320554
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_22
# ----------------------------------
# | time/              |           |
# |    fps             | 109       |
# |    iterations      | 1         |
# |    time_elapsed    | 18        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 0.6477687 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 2           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.01835522  |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.8       |
# |    explained_variance   | -0.0177     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.79        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0235     |
# |    reward               | -0.04298923 |
# |    std                  | 1           |
# |    value_loss           | 11.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 3           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.020313732 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.9       |
# |    explained_variance   | 0.00171     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 26.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0193     |
# |    reward               | -1.0429584  |
# |    std                  | 1.01        |
# |    value_loss           | 60.7        |
# -----------------------------------------
# day: 3817, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 2939539.07
# total_reward: 1939539.07
# total_cost: 410513.16
# total_trades: 102096
# Sharpe: 0.461
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 4           |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.020249272 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -40         |
# |    explained_variance   | -0.0313     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.53        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0263     |
# |    reward               | 2.4332666   |
# |    std                  | 1.01        |
# |    value_loss           | 9.02        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 5           |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020640153 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -40.1       |
# |    explained_variance   | -0.00146    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 26.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0228     |
# |    reward               | 0.32851237  |
# |    std                  | 1.01        |
# |    value_loss           | 30.7        |
# -----------------------------------------
# ======PPO Validation from:  2021-03-05 to  2021-06-04
# PPO Sharpe Ratio:  0.4216357959912961
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_189_21
# ======DDPG Validation from:  2021-03-05 to  2021-06-04
# ======Best Model Retraining from:  2006-01-01 to  2021-06-04
# ======Trading from:  2021-06-04 to  2021-09-02
# ============================================
# turbulence_threshold:  202.91028385393966
# ======Model training from:  2006-01-01 to  2021-06-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_252_21
# -------------------------------------
# | time/                 |           |
# |    fps                | 97        |
# |    iterations         | 100       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -40       |
# |    explained_variance | -0.362    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 99        |
# |    policy_loss        | 14.4      |
# |    reward             | 0.1385583 |
# |    std                | 1.01      |
# |    value_loss         | 0.775     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 98         |
# |    iterations         | 200        |
# |    time_elapsed       | 10         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | 0.296      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 199        |
# |    policy_loss        | -3.25      |
# |    reward             | 0.58665526 |
# |    std                | 1.01       |
# |    value_loss         | 1.25       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 99        |
# |    iterations         | 300       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -40       |
# |    explained_variance | -0.218    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 299       |
# |    policy_loss        | -13.8     |
# |    reward             | 1.1403419 |
# |    std                | 1.01      |
# |    value_loss         | 0.232     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 99        |
# |    iterations         | 400       |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -40       |
# |    explained_variance | 0.295     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 399       |
# |    policy_loss        | -52.3     |
# |    reward             | -1.421407 |
# |    std                | 1.01      |
# |    value_loss         | 2.96      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 500        |
# |    time_elapsed       | 24         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | -1.07      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 499        |
# |    policy_loss        | 17.4       |
# |    reward             | -1.8675867 |
# |    std                | 1.01       |
# |    value_loss         | 0.895      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 600        |
# |    time_elapsed       | 29         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -40.1      |
# |    explained_variance | 0.0928     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 599        |
# |    policy_loss        | 9.61       |
# |    reward             | 0.68332344 |
# |    std                | 1.01       |
# |    value_loss         | 0.586      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 700       |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -40       |
# |    explained_variance | 0.0232    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 699       |
# |    policy_loss        | 63.8      |
# |    reward             | 0.8971396 |
# |    std                | 1.01      |
# |    value_loss         | 9.31      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 100          |
# |    iterations         | 800          |
# |    time_elapsed       | 39           |
# |    total_timesteps    | 4000         |
# | train/                |              |
# |    entropy_loss       | -40          |
# |    explained_variance | -0.0529      |
# |    learning_rate      | 0.0005       |
# |    n_updates          | 799          |
# |    policy_loss        | 15.2         |
# |    reward             | -0.023305843 |
# |    std                | 1.01         |
# |    value_loss         | 0.482        |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 900        |
# |    time_elapsed       | 45         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | -0.117     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 899        |
# |    policy_loss        | -92.6      |
# |    reward             | 0.40369675 |
# |    std                | 1.01       |
# |    value_loss         | 8.64       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1000     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -40.1    |
# |    explained_variance | 0.112    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 999      |
# |    policy_loss        | -18.7    |
# |    reward             | 1.499547 |
# |    std                | 1.01     |
# |    value_loss         | 1.27     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 99        |
# |    iterations         | 1100      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -40.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1099      |
# |    policy_loss        | 1.64      |
# |    reward             | 0.1345459 |
# |    std                | 1.01      |
# |    value_loss         | 0.0567    |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 100          |
# |    iterations         | 1200         |
# |    time_elapsed       | 59           |
# |    total_timesteps    | 6000         |
# | train/                |              |
# |    entropy_loss       | -40.1        |
# |    explained_variance | -0.0408      |
# |    learning_rate      | 0.0005       |
# |    n_updates          | 1199         |
# |    policy_loss        | 68.6         |
# |    reward             | 0.0036535817 |
# |    std                | 1.01         |
# |    value_loss         | 2.71         |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 99          |
# |    iterations         | 1300        |
# |    time_elapsed       | 65          |
# |    total_timesteps    | 6500        |
# | train/                |             |
# |    entropy_loss       | -40.1       |
# |    explained_variance | -0.00491    |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1299        |
# |    policy_loss        | 1.14        |
# |    reward             | -0.13201155 |
# |    std                | 1.01        |
# |    value_loss         | 0.706       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 1400       |
# |    time_elapsed       | 70         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -40.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1399       |
# |    policy_loss        | -55.9      |
# |    reward             | -1.3383578 |
# |    std                | 1.01       |
# |    value_loss         | 4.26       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 1500       |
# |    time_elapsed       | 75         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -40.1      |
# |    explained_variance | -0.0596    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1499       |
# |    policy_loss        | -31.9      |
# |    reward             | 0.19471851 |
# |    std                | 1.01       |
# |    value_loss         | 4.59       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 98         |
# |    iterations         | 1600       |
# |    time_elapsed       | 81         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -40.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1599       |
# |    policy_loss        | -11.9      |
# |    reward             | -0.3544461 |
# |    std                | 1.01       |
# |    value_loss         | 0.449      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 98        |
# |    iterations         | 1700      |
# |    time_elapsed       | 86        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -40.1     |
# |    explained_variance | 0.102     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1699      |
# |    policy_loss        | -111      |
# |    reward             | 0.9790226 |
# |    std                | 1.01      |
# |    value_loss         | 8.05      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 98         |
# |    iterations         | 1800       |
# |    time_elapsed       | 91         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -40.1      |
# |    explained_variance | 0.109      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1799       |
# |    policy_loss        | -13.8      |
# |    reward             | 0.99262077 |
# |    std                | 1.01       |
# |    value_loss         | 0.454      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 98        |
# |    iterations         | 1900      |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -40.2     |
# |    explained_variance | 0.0199    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1899      |
# |    policy_loss        | 36.1      |
# |    reward             | 1.1561615 |
# |    std                | 1.02      |
# |    value_loss         | 1.21      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 98         |
# |    iterations         | 2000       |
# |    time_elapsed       | 101        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -40.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1999       |
# |    policy_loss        | -58.7      |
# |    reward             | 0.38501236 |
# |    std                | 1.02       |
# |    value_loss         | 2.22       |
# --------------------------------------
# ======A2C Validation from:  2021-06-04 to  2021-09-02
# A2C Sharpe Ratio:  0.025004914056192325
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_252_21
# -----------------------------------
# | time/              |            |
# |    fps             | 107        |
# |    iterations      | 1          |
# |    time_elapsed    | 19         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.48301235 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# ...
# |    entropy_loss       | -39.9      |
# |    explained_variance | 0.0266     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 199        |
# |    policy_loss        | 7.09       |
# |    reward             | 0.17568809 |
# |    std                | 1.01       |
# |    value_loss         | 0.593      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 300       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 299       |
# |    policy_loss        | -34.3     |
# |    reward             | 1.2666253 |
# |    std                | 1.01      |
# |    value_loss         | 2.03      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 400        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | -0.244     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 399        |
# |    policy_loss        | -60.7      |
# |    reward             | -1.9415833 |
# |    std                | 1.01       |
# |    value_loss         | 3.28       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 500        |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 499        |
# |    policy_loss        | 187        |
# |    reward             | -1.0882982 |
# |    std                | 1.01       |
# |    value_loss         | 23.6       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 90        |
# |    iterations         | 600       |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -40       |
# |    explained_variance | 0.126     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 599       |
# |    policy_loss        | 99.2      |
# |    reward             | -3.087711 |
# |    std                | 1.01      |
# |    value_loss         | 8.69      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 91         |
# |    iterations         | 700        |
# |    time_elapsed       | 38         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -40.1      |
# |    explained_variance | 2.38e-07   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 699        |
# |    policy_loss        | 563        |
# |    reward             | -1.0980517 |
# |    std                | 1.01       |
# |    value_loss         | 423        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 93         |
# |    iterations         | 800        |
# |    time_elapsed       | 42         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | -0.617     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 799        |
# |    policy_loss        | 30.6       |
# |    reward             | 0.14689983 |
# |    std                | 1.01       |
# |    value_loss         | 1.02       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 94         |
# |    iterations         | 900        |
# |    time_elapsed       | 47         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | 8.73e-05   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 899        |
# |    policy_loss        | -124       |
# |    reward             | 0.78473294 |
# |    std                | 1.01       |
# |    value_loss         | 21.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 95         |
# |    iterations         | 1000       |
# |    time_elapsed       | 52         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 999        |
# |    policy_loss        | -13.2      |
# |    reward             | 0.93290603 |
# |    std                | 1.01       |
# |    value_loss         | 0.456      |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 96       |
# |    iterations         | 1100     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -40      |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1099     |
# |    policy_loss        | 40.6     |
# |    reward             | 2.35394  |
# |    std                | 1.01     |
# |    value_loss         | 1.48     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 97         |
# |    iterations         | 1200       |
# |    time_elapsed       | 61         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | -0.00039   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1199       |
# |    policy_loss        | 111        |
# |    reward             | -0.6128735 |
# |    std                | 1.01       |
# |    value_loss         | 12.3       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 97       |
# |    iterations         | 1300     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -40      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1299     |
# |    policy_loss        | 276      |
# |    reward             | 6.71253  |
# |    std                | 1.01     |
# |    value_loss         | 77.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 97       |
# |    iterations         | 1400     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -40      |
# |    explained_variance | 2.38e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1399     |
# |    policy_loss        | 224      |
# |    reward             | 8.204419 |
# |    std                | 1.01     |
# |    value_loss         | 181      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 98        |
# |    iterations         | 1500      |
# |    time_elapsed       | 76        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -40       |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1499      |
# |    policy_loss        | 1.34e+03  |
# |    reward             | -8.773125 |
# |    std                | 1.01      |
# |    value_loss         | 1.13e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 98        |
# |    iterations         | 1600      |
# |    time_elapsed       | 81        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -40       |
# |    explained_variance | 0.153     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1599      |
# |    policy_loss        | -18.6     |
# |    reward             | 1.0458378 |
# |    std                | 1.01      |
# |    value_loss         | 0.676     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 99          |
# |    iterations         | 1700        |
# |    time_elapsed       | 85          |
# |    total_timesteps    | 8500        |
# | train/                |             |
# |    entropy_loss       | -40         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1699        |
# |    policy_loss        | -28.1       |
# |    reward             | -0.24385966 |
# |    std                | 1.01        |
# |    value_loss         | 0.732       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 99          |
# |    iterations         | 1800        |
# |    time_elapsed       | 90          |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -40.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1799        |
# |    policy_loss        | 58.9        |
# |    reward             | -0.90356576 |
# |    std                | 1.01        |
# |    value_loss         | 2.55        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 99        |
# |    iterations         | 1900      |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -40.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1899      |
# |    policy_loss        | 89.6      |
# |    reward             | 0.7596289 |
# |    std                | 1.01      |
# |    value_loss         | 7.61      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 2000     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -40.1    |
# |    explained_variance | -0.121   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1999     |
# |    policy_loss        | 5.85     |
# |    reward             | 1.502632 |
# |    std                | 1.01     |
# |    value_loss         | 2.28     |
# ------------------------------------
# ======A2C Validation from:  2021-09-02 to  2021-12-02
# A2C Sharpe Ratio:  0.08289335870877197
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_315_19
# ----------------------------------
# | time/              |           |
# |    fps             | 97        |
# |    iterations      | 1         |
# |    time_elapsed    | 20        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 0.5135599 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 2           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.020595627 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.8       |
# |    explained_variance   | -0.0264     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.69        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0244     |
# |    reward               | 0.09940861  |
# |    std                  | 1           |
# |    value_loss           | 8.18        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 3           |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015230005 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.8       |
# |    explained_variance   | 0.0045      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0197     |
# |    reward               | -0.08358934 |
# |    std                  | 1           |
# |    value_loss           | 62.3        |
# -----------------------------------------
# day: 3943, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4490967.77
# total_reward: 3490967.77
# total_cost: 442982.00
# total_trades: 105554
# Sharpe: 0.576
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 4           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.021237042 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.8       |
# |    explained_variance   | 0.0511      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.46        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0224     |
# |    reward               | 1.7576783   |
# |    std                  | 1           |
# |    value_loss           | 8.29        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 5          |
# |    time_elapsed         | 105        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.02530596 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -39.9      |
# |    explained_variance   | -0.0729    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 34.7       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.022     |
# |    reward               | 1.1646669  |
# |    std                  | 1.01       |
# |    value_loss           | 51.9       |
# ----------------------------------------
# ======PPO Validation from:  2021-09-02 to  2021-12-02
# PPO Sharpe Ratio:  -0.09247863295496729
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_315_17
# ======DDPG Validation from:  2021-09-02 to  2021-12-02
# ======Best Model Retraining from:  2006-01-01 to  2021-12-02
# ======Trading from:  2021-12-02 to  2022-03-04
# Ensemble Strategy took:  27.14835481643677  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2020-12-02  2021-03-05       DDPG   0.003088   0.103442    0.170474
# 1  189  2021-03-05  2021-06-04       DDPG   0.325797   0.421636    0.464576
# 2  252  2021-06-04  2021-09-02       DDPG   0.025005   0.096628    0.114662
# 3  315  2021-09-02  2021-12-02        A2C   0.082893  -0.092479   -0.293537

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > val_test_start)&(processed.date <= val_test_end)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  0.9373513641383824

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2021-03-05           NaN  2021-03-05
# 1   1.001835e+06  2021-03-08      0.001835  2021-03-08
# 2   1.002280e+06  2021-03-09      0.000444  2021-03-09
# 3   1.006420e+06  2021-03-10      0.004131  2021-03-10
# 4   1.008363e+06  2021-03-11      0.001931  2021-03-11

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.155136
# Cumulative returns     0.155136
# Annual volatility      0.169463
# Sharpe ratio           0.937351
# Calmar ratio           1.893439
# Stability              0.668272
# Max drawdown          -0.081933
# Omega ratio            1.196248
# Sortino ratio          1.666730
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.127743
# Daily value at risk   -0.020720
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.076357
# Cumulative returns     0.076042
# Annual volatility      0.128444
# Sharpe ratio           0.639265
# Calmar ratio           0.766080
# Stability              0.396026
# Max drawdown          -0.099672
# Omega ratio            1.110797
# Sortino ratio          0.907534
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.952372
# Daily value at risk   -0.015857
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-03-05</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-03-03</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>15.514%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>15.514%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>16.946%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.94</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.89</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.67</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-8.193%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.20</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.67</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.13</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.072%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.08</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.97</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8.19</td>
#       <td>2022-01-04</td>
#       <td>2022-02-24</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6.54</td>
#       <td>2021-08-27</td>
#       <td>2021-09-30</td>
#       <td>2021-11-02</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.70</td>
#       <td>2021-11-02</td>
#       <td>2021-12-01</td>
#       <td>2022-01-04</td>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.60</td>
#       <td>2021-06-04</td>
#       <td>2021-06-18</td>
#       <td>2021-06-30</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.71</td>
#       <td>2021-07-12</td>
#       <td>2021-07-19</td>
#       <td>2021-08-03</td>
#       <td>17</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.06%</td>
#       <td>-2.43%</td>
#       <td>9.77%</td>
#     </tr>
#   </tbody>
# </table>
