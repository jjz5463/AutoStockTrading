# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy - Modified: tech indicator
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# install finrl library
# !git clone https://github.com/AI4Finance-LLC/FinRL-Library.git

# %%
import sys
sys.path.append("FinRL-Library")

# %%
# install packages
#!pip install yfinance

# %%
# !pip install stockstats
# Out:
# Requirement already satisfied: stockstats in /opt/anaconda3/lib/python3.8/site-packages (0.4.1)
# Requirement already satisfied: pandas>=0.24.2 in /opt/anaconda3/lib/python3.8/site-packages (from stockstats) (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.2->stockstats) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.2->stockstats) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.2->stockstats) (2021.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.2->stockstats) (1.16.0)

# %%
#!pip install git+https://github.com/quantopian/pyfolio

# %%
# ## install finrl library
#!pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.apps import config
from finrl.finrl_meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.finrl_meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.finrl_meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.drl_agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
# from config.py start_date is a string
#config.START_DATE

# %%
fav = ["NIO", "TSLA", "AAPL", "DIS", "TWTR", "NFLX", 
       "NVDA", "EDU", "DDOG", "XPEV", "GFI", "SQQQ", 
       "TQQQ", "PDD"]
#print(config.DOW_30_TICKER)

# %%
# I changed the end datae to yesterday, original date is 2021-07-06
df = YahooDownloader(start_date = '2006-01-01',
                     end_date = '2022-03-21',
                     ticker_list = fav).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (38288, 8)

# %%
df.head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2006-01-03   2.585000   2.669643   2.580357   2.285948  807234400  AAPL
# 1  2006-01-03  23.754919  24.149521  23.676001  20.019037    9789559   DIS
# 2  2006-01-03  15.813953  16.795866  15.736434  12.382147    3321505   GFI
# 3  2006-01-03   3.865714   3.874286   3.588571   3.721429   15659700  NFLX
# 4  2006-01-03   3.064167   3.208333   3.054167   2.925477   47281200  NVDA
#
#    day
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
df.tail()
# Out:
#              date        open        high         low       close     volume  \
# 38283  2022-03-18   40.490002   40.900002   37.330002   37.490002   98941400
# 38284  2022-03-18   49.459999   53.410000   48.930000   53.169998  100576200
# 38285  2022-03-18  874.489990  907.849976  867.390015  905.390015   33408500
# 38286  2022-03-18   37.459999   39.049999   37.180000   37.770000   35946300
# 38287  2022-03-18   25.309999   29.639999   24.969999   28.770000   27982700
#
#         tic  day
# 38283  SQQQ    4
# 38284  TQQQ    4
# 38285  TSLA    4
# 38286  TWTR    4
# 38287  XPEV    4

# %%
df.shape
# Out:
# (38288, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2006-01-03   2.585000   2.669643   2.580357   2.285948  807234400  AAPL
# 1  2006-01-03  23.754919  24.149521  23.676001  20.019037    9789559   DIS
# 2  2006-01-03  15.813953  16.795866  15.736434  12.382147    3321505   GFI
# 3  2006-01-03   3.865714   3.874286   3.588571   3.721429   15659700  NFLX
# 4  2006-01-03   3.064167   3.208333   3.054167   2.925477   47281200  NVDA
#
#    day
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
len(df.tic.unique())
# Out:
# 14

# %%
df.tic.value_counts()
# Out:
# AAPL    4081
# DIS     4081
# GFI     4081
# NFLX    4081
# NVDA    4081
# EDU     3904
# SQQQ    3047
# TQQQ    3047
# TSLA    2952
# TWTR    2105
# PDD      919
# NIO      886
# DDOG     630
# XPEV     393
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
# added indicators
tech_indicators = [    #"boll_ub", "boll_lb", # this two are new
'macd',
 'rsi_30',
 'cci_30',
 'dx_30']

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = tech_indicators,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.sample(5)
# Out:
#              date        open        high         low       close    volume  \
# 8691   2012-11-28   48.470001   49.250000   47.840000   44.050915   8148500
# 9133   2013-04-08   23.690001   23.757143   22.714287   23.294287  31745000
# 20188  2022-01-14  517.599976  538.369995  511.880005  525.690002   7861100
# 4423   2009-07-09    5.615714    5.734286    5.588571    5.707143  12084100
# 1386   2007-02-09   34.724800   34.823448   33.462078   28.449574  19246224
#
#         tic  day       macd     rsi_30      cci_30      dx_30  turbulence
# 8691    DIS    2  -0.442466  47.954247  -43.285773  21.812275    1.256368
# 9133   NFLX    0  -0.329048  49.637044 -273.189088  21.401262    3.488141
# 20188  NFLX    4 -25.212277  34.160892 -168.566112  64.091675    3.217980
# 4423   NFLX    3  -0.018862  49.550693   -0.936243   6.497238    1.431336
# 1386    DIS    4   0.121423  51.431547  -66.925672   5.797051    9.221391

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(tech_indicators)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 5, State Space: 31

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": tech_indicators,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)
train_start = '2006-01-01'
train_end = '2020-12-01' #original is 2020-4-1
val_test_start = '2020-12-01' #original is 2020-4-1
val_test_end = '2022-03-21'#original is 2021-7-06

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(train_start,train_end),
                 val_test_period=(val_test_start,val_test_end),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.01,
                    'learning_rate': 0.0005
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 64
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 100_000,
                      "learning_rate": 0.000005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 30_000, 
                 'ppo' : 100_000, 
                 'ddpg' : 10_000
                 }


timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  45.597279818352945
# ======Model training from:  2006-01-01 to  2020-12-02
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_126_40
# ---------------------------------------
# | time/                 |             |
# |    fps                | 386         |
# |    iterations         | 100         |
# |    time_elapsed       | 1           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -7.26       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 99          |
# |    policy_loss        | 3.06        |
# |    reward             | -0.16379133 |
# |    std                | 1.03        |
# |    value_loss         | 0.18        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 386        |
# |    iterations         | 200        |
# |    time_elapsed       | 2          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -7.29      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 199        |
# |    policy_loss        | 5.36       |
# |    reward             | 0.13387306 |
# |    std                | 1.04       |
# |    value_loss         | 0.835      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 390        |
# |    iterations         | 300        |
# |    time_elapsed       | 3          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -7.31      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 299        |
# |    policy_loss        | -12.2      |
# |    reward             | -1.2230225 |
# |    std                | 1.04       |
# |    value_loss         | 4.63       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 391       |
# |    iterations         | 400       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -7.32     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 399       |
# |    policy_loss        | -26       |
# |    reward             | 5.2075915 |
# |    std                | 1.05      |
# |    value_loss         | 15.8      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 391      |
# |    iterations         | 500      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -7.33    |
# |    explained_variance | -0.0169  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 499      |
# |    policy_loss        | 64.1     |
# |    reward             | 8.364303 |
# |    std                | 1.05     |
# |    value_loss         | 79.9     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 392        |
# |    iterations         | 600        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -7.35      |
# |    explained_variance | 0.000869   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 599        |
# |    policy_loss        | 95         |
# |    reward             | -11.175427 |
# |    std                | 1.05       |
# |    value_loss         | 219        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 392       |
# |    iterations         | 700       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -7.35     |
# |    explained_variance | 0.0111    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 699       |
# |    policy_loss        | 340       |
# |    reward             | 18.118917 |
# |    std                | 1.05      |
# |    value_loss         | 3.43e+03  |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 393         |
# |    iterations         | 800         |
# |    time_elapsed       | 10          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -7.37       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 799         |
# |    policy_loss        | 1.7         |
# |    reward             | -0.19263083 |
# |    std                | 1.06        |
# |    value_loss         | 0.0708      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 395        |
# |    iterations         | 900        |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -7.37      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 899        |
# |    policy_loss        | 26.3       |
# |    reward             | -0.4467217 |
# |    std                | 1.06       |
# |    value_loss         | 21.6       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 396       |
# |    iterations         | 1000      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -7.37     |
# |    explained_variance | -0.00146  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 999       |
# |    policy_loss        | -5.35     |
# |    reward             | -8.011679 |
# |    std                | 1.06      |
# |    value_loss         | 12.6      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 396        |
# |    iterations         | 1100       |
# |    time_elapsed       | 13         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -7.39      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1099       |
# |    policy_loss        | -5         |
# |    reward             | -1.1101605 |
# |    std                | 1.06       |
# |    value_loss         | 0.799      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 396       |
# |    iterations         | 1200      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -7.4      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1199      |
# |    policy_loss        | -84.7     |
# |    reward             | 4.2575583 |
# |    std                | 1.06      |
# |    value_loss         | 171       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 397        |
# |    iterations         | 1300       |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -7.4       |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1299       |
# |    policy_loss        | 132        |
# |    reward             | -2.8591788 |
# |    std                | 1.06       |
# |    value_loss         | 596        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 396        |
# |    iterations         | 1400       |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -7.39      |
# |    explained_variance | -0.000219  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1399       |
# |    policy_loss        | -1.05e+03  |
# |    reward             | -39.768898 |
# |    std                | 1.06       |
# |    value_loss         | 2.69e+04   |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 395        |
# |    iterations         | 1500       |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -7.38      |
# |    explained_variance | -1.94e-05  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1499       |
# |    policy_loss        | -1.61e+03  |
# |    reward             | -7.0446243 |
# |    std                | 1.06       |
# |    value_loss         | 7.44e+04   |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 394         |
# |    iterations         | 1600        |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -7.39       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1599        |
# |    policy_loss        | 10.8        |
# |    reward             | -0.71400833 |
# |    std                | 1.06        |
# |    value_loss         | 2.82        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 394       |
# |    iterations         | 1700      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -7.38     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1699      |
# |    policy_loss        | -4.7      |
# |    reward             | -1.344876 |
# |    std                | 1.06      |
# |    value_loss         | 1.68      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 393      |
# |    iterations         | 1800     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -7.37    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1799     |
# |    policy_loss        | -78.7    |
# |    reward             | 3.715375 |
# |    std                | 1.06     |
# |    value_loss         | 103      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 394       |
# |    iterations         | 1900      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -7.39     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1899      |
# |    policy_loss        | -45.9     |
# |    reward             | 8.846687  |
# |    std                | 1.06      |
# |    value_loss         | 56.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 394       |
# |    iterations         | 2000      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -7.4      |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1999      |
# |    policy_loss        | 57.5      |
# |    reward             | 7.295088  |
# |    std                | 1.06      |
# |    value_loss         | 919       |
# -------------------------------------
# ======A2C Validation from:  2020-12-02 to  2021-03-05
# A2C Sharpe Ratio:  -0.021281415266570857
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_38
# -----------------------------------
# | time/              |            |
# |    fps             | 442        |
# |    iterations      | 1          |
# |    time_elapsed    | 4          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.73650205 |
# -----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0038680993 |
# |    clip_fraction        | 0.0563       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.11        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.154        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00277     |
# |    reward               | -0.082241796 |
# |    std                  | 1.01         |
# |    value_loss           | 0.547        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 3            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0040429966 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.12        |
# |    explained_variance   | 6.22e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 82.1         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00352     |
# |    reward               | -0.083163865 |
# |    std                  | 1.01         |
# |    value_loss           | 139          |
# ------------------------------------------
# day: 3754, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 8897529.66
# total_reward: 7897529.66
# total_cost: 49069.27
# total_trades: 18184
# Sharpe: 0.734
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006883276 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.12       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0032     |
# |    reward               | 0.41633093  |
# |    std                  | 1           |
# |    value_loss           | 12.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 5           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.003916668 |
# |    clip_fraction        | 0.00972     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.11       |
# |    explained_variance   | 0.000744    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 392         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00342    |
# |    reward               | -0.30063382 |
# |    std                  | 1           |
# |    value_loss           | 690         |
# -----------------------------------------
# ======PPO Validation from:  2020-12-02 to  2021-03-05
# PPO Sharpe Ratio:  -0.05340969562637474
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_126_32
# ======DDPG Validation from:  2020-12-02 to  2021-03-05
# ======Best Model Retraining from:  2006-01-01 to  2021-03-05
# ======Trading from:  2021-03-05 to  2021-06-04
# ============================================
# turbulence_threshold:  45.597279818352945
# ======Model training from:  2006-01-01 to  2021-03-05
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_189_30
# ----------------------------------------
# | time/                 |              |
# |    fps                | 346          |
# |    iterations         | 100          |
# |    time_elapsed       | 1            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -7.24        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0005       |
# |    n_updates          | 99           |
# |    policy_loss        | 0.104        |
# |    reward             | -0.007913648 |
# |    std                | 1.03         |
# |    value_loss         | 0.000994     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 351          |
# |    iterations         | 200          |
# |    time_elapsed       | 2            |
# |    total_timesteps    | 1000         |
# | train/                |              |
# |    entropy_loss       | -7.27        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0005       |
# |    n_updates          | 199          |
# |    policy_loss        | 6.07         |
# |    reward             | -0.082147665 |
# |    std                | 1.04         |
# |    value_loss         | 0.92         |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 359         |
# |    iterations         | 300         |
# |    time_elapsed       | 4           |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -7.27       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 299         |
# |    policy_loss        | -4.34       |
# |    reward             | -0.08927466 |
# |    std                | 1.04        |
# |    value_loss         | 0.582       |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 364          |
# |    iterations         | 400          |
# |    time_elapsed       | 5            |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -7.29        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0005       |
# |    n_updates          | 399          |
# |    policy_loss        | -4.15        |
# |    reward             | -0.031978376 |
# |    std                | 1.04         |
# |    value_loss         | 0.357        |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 366       |
# |    iterations         | 500       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -7.3      |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 499       |
# |    policy_loss        | 7.56      |
# |    reward             | 0.7013633 |
# |    std                | 1.04      |
# |    value_loss         | 1.37      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 368        |
# |    iterations         | 600        |
# |    time_elapsed       | 8          |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -7.29      |
# |    explained_variance | 0.00806    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 599        |
# |    policy_loss        | 21.5       |
# |    reward             | -3.3501976 |
# |    std                | 1.04       |
# |    value_loss         | 14.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 369       |
# |    iterations         | 700       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -7.31     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 699       |
# |    policy_loss        | 50.5      |
# |    reward             | 2.7669282 |
# |    std                | 1.04      |
# |    value_loss         | 86.2      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 370        |
# |    iterations         | 800        |
# |    time_elapsed       | 10         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -7.31      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 799        |
# |    policy_loss        | -3.19      |
# |    reward             | 0.24751967 |
# |    std                | 1.04       |
# |    value_loss         | 0.602      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 371       |
# |    iterations         | 900       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -7.32     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 899       |
# |    policy_loss        | -17.8     |
# |    reward             | 1.7632705 |
# |    std                | 1.05      |
# |    value_loss         | 5.19      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 373       |
# |    iterations         | 1000      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -7.33     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 999       |
# |    policy_loss        | 17.5      |
# |    reward             | 1.4344006 |
# |    std                | 1.05      |
# |    value_loss         | 5.08      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 374       |
# |    iterations         | 1100      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -7.34     |
# |    explained_variance | -0.0758   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1099      |
# |    policy_loss        | -24.9     |
# |    reward             | 2.5167997 |
# |    std                | 1.05      |
# |    value_loss         | 15.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 375        |
# |    iterations         | 1200       |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -7.35      |
# |    explained_variance | 0.0188     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1199       |
# |    policy_loss        | 10.8       |
# |    reward             | -0.7116144 |
# |    std                | 1.05       |
# |    value_loss         | 2.63       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 376        |
# |    iterations         | 1300       |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -7.34      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1299       |
# |    policy_loss        | -6.02      |
# |    reward             | -1.8038005 |
# |    std                | 1.05       |
# |    value_loss         | 1.49       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 1400     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -7.35    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1399     |
# |    policy_loss        | -32.9    |
# |    reward             | 4.348959 |
# |    std                | 1.05     |
# |    value_loss         | 30.2     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 377        |
# |    iterations         | 1500       |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -7.36      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1499       |
# |    policy_loss        | 27.3       |
# |    reward             | -10.783401 |
# |    std                | 1.05       |
# |    value_loss         | 197        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 377       |
# |    iterations         | 1600      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -7.38     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1599      |
# |    policy_loss        | -4.32     |
# |    reward             | 0.6474821 |
# |    std                | 1.06      |
# |    value_loss         | 0.645     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 377         |
# |    iterations         | 1700        |
# |    time_elapsed       | 22          |
# |    total_timesteps    | 8500        |
# | train/                |             |
# |    entropy_loss       | -7.39       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1699        |
# |    policy_loss        | -8.94       |
# |    reward             | -0.46112722 |
# |    std                | 1.06        |
# |    value_loss         | 3.36        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 377        |
# |    iterations         | 1800       |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -7.42      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1799       |
# |    policy_loss        | 13.6       |
# |    reward             | -1.6332906 |
# |    std                | 1.07       |
# |    value_loss         | 4.79       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 378        |
# |    iterations         | 1900       |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -7.43      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1899       |
# |    policy_loss        | -3.88      |
# |    reward             | -1.7339301 |
# |    std                | 1.07       |
# |    value_loss         | 0.792      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 378       |
# |    iterations         | 2000      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -7.43     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1999      |
# |    policy_loss        | -11.2     |
# |    reward             | 2.8101225 |
# |    std                | 1.07      |
# |    value_loss         | 2.51      |
# -------------------------------------
# ======A2C Validation from:  2021-03-05 to  2021-06-04
# A2C Sharpe Ratio:  0.17042634286009337
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_30
# ----------------------------------
# | time/              |           |
# |    fps             | 425       |
# |    iterations      | 1         |
# |    time_elapsed    | 4         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 0.7757073 |
# ----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 404          |
# |    iterations           | 2            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.00545389   |
# |    clip_fraction        | 0.0793       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.11        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.506        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00423     |
# |    reward               | -0.027996127 |
# |    std                  | 1            |
# |    value_loss           | 1.25         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 398          |
# |    iterations           | 3            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0028308337 |
# |    clip_fraction        | 0.00762      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.12        |
# |    explained_variance   | 0.00596      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 66.1         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00356     |
# |    reward               | -0.1480446   |
# |    std                  | 1.01         |
# |    value_loss           | 191          |
# ------------------------------------------
# day: 3817, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 6003319.13
# total_reward: 5003319.13
# total_cost: 54386.12
# total_trades: 18666
# Sharpe: 0.726
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 4            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0073653855 |
# |    clip_fraction        | 0.0766       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.13        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.408        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.004       |
# |    reward               | 0.18339287   |
# |    std                  | 1.01         |
# |    value_loss           | 1.3          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 392          |
# |    iterations           | 5            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0013920427 |
# |    clip_fraction        | 0.000342     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.13        |
# |    explained_variance   | 0.0315       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 102          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00215     |
# |    reward               | -0.45859298  |
# |    std                  | 1.01         |
# |    value_loss           | 244          |
# ------------------------------------------
# ======PPO Validation from:  2021-03-05 to  2021-06-04
# PPO Sharpe Ratio:  -0.14555256508101247
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_189_29
# ======DDPG Validation from:  2021-03-05 to  2021-06-04
# ======Best Model Retraining from:  2006-01-01 to  2021-06-04
# ======Trading from:  2021-06-04 to  2021-09-02
# ============================================
# turbulence_threshold:  45.597279818352945
# ======Model training from:  2006-01-01 to  2021-06-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_252_29
# ---------------------------------------
# | time/                 |             |
# |    fps                | 330         |
# |    iterations         | 100         |
# |    time_elapsed       | 1           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -7.15       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 99          |
# |    policy_loss        | 5.7         |
# |    reward             | -0.12856136 |
# |    std                | 1.01        |
# |    value_loss         | 0.658       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 334         |
# |    iterations         | 200         |
# |    time_elapsed       | 2           |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -7.15       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 199         |
# |    policy_loss        | 13.9        |
# |    reward             | -0.13714452 |
# |    std                | 1.01        |
# |    value_loss         | 6.24        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 336        |
# |    iterations         | 300        |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -7.14      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 299        |
# |    policy_loss        | -7.2       |
# |    reward             | -1.0657763 |
# |    std                | 1.01       |
# |    value_loss         | 5.95       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 338      |
# |    iterations         | 400      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -7.15    |
# |    explained_variance | -0.198   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 399      |
# |    policy_loss        | -10.3    |
# |    reward             | 5.821091 |
# |    std                | 1.01     |
# |    value_loss         | 9.5      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 340       |
# |    iterations         | 500       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -7.14     |
# |    explained_variance | 0.011     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 499       |
# |    policy_loss        | 5.33      |
# |    reward             | 3.0091455 |
# |    std                | 1.01      |
# |    value_loss         | 51.2      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 342        |
# |    iterations         | 600        |
# |    time_elapsed       | 8          |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -7.12      |
# |    explained_variance | -0.0212    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 599        |
# |    policy_loss        | 23.6       |
# |    reward             | -3.0829291 |
# |    std                | 1.01       |
# |    value_loss         | 59.8       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 345      |
# |    iterations         | 700      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -7.11    |
# |    explained_variance | 0.00762  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 699      |
# |    policy_loss        | 260      |
# |    reward             | 18.65013 |
# |    std                | 1        |
# |    value_loss         | 2.7e+03  |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 345        |
# |    iterations         | 800        |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -7.13      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 799        |
# |    policy_loss        | 1.86       |
# |    reward             | -0.1240952 |
# |    std                | 1.01       |
# |    value_loss         | 0.198      |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 900      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -7.14    |
# |    explained_variance | -0.028   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 899      |
# |    policy_loss        | -17      |
# |    reward             | 0.814376 |
# |    std                | 1.01     |
# |    value_loss         | 10.6     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 347       |
# |    iterations         | 1000      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -7.16     |
# |    explained_variance | 0.00679   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 999       |
# |    policy_loss        | -16.3     |
# |    reward             | 1.2813555 |
# |    std                | 1.01      |
# |    value_loss         | 11.3      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 347         |
# |    iterations         | 1100        |
# |    time_elapsed       | 15          |
# |    total_timesteps    | 5500        |
# | train/                |             |
# |    entropy_loss       | -7.18       |
# |    explained_variance | -0.253      |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1099        |
# |    policy_loss        | -11         |
# |    reward             | -0.57765126 |
# |    std                | 1.02        |
# |    value_loss         | 2.87        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 347       |
# |    iterations         | 1200      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -7.19     |
# |    explained_variance | -0.00104  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1199      |
# |    policy_loss        | 92.5      |
# |    reward             | 4.4272175 |
# |    std                | 1.02      |
# |    value_loss         | 231       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 348       |
# |    iterations         | 1300      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -7.17     |
# |    explained_variance | 0.0465    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1299      |
# |    policy_loss        | 192       |
# |    reward             | -5.420471 |
# |    std                | 1.02      |
# |    value_loss         | 664       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 348       |
# |    iterations         | 1400      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -7.16     |
# |    explained_variance | -0.0014   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1399      |
# |    policy_loss        | -97.4     |
# |    reward             | 24.012306 |
# |    std                | 1.01      |
# |    value_loss         | 231       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 349        |
# |    iterations         | 1500       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -7.15      |
# |    explained_variance | 0.00355    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1499       |
# |    policy_loss        | 89.7       |
# |    reward             | -10.461233 |
# |    std                | 1.01       |
# |    value_loss         | 458        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 349         |
# |    iterations         | 1600        |
# |    time_elapsed       | 22          |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -7.17       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1599        |
# |    policy_loss        | 3.54        |
# |    reward             | -0.20362541 |
# |    std                | 1.02        |
# |    value_loss         | 0.345       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 349       |
# |    iterations         | 1700      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -7.18     |
# |    explained_variance | 0.00153   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1699      |
# |    policy_loss        | -21.4     |
# |    reward             | 4.3638973 |
# |    std                | 1.02      |
# |    value_loss         | 15.3      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 348        |
# |    iterations         | 1800       |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -7.17      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1799       |
# |    policy_loss        | 72.4       |
# |    reward             | -5.0330396 |
# |    std                | 1.02       |
# |    value_loss         | 172        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 348         |
# |    iterations         | 1900        |
# |    time_elapsed       | 27          |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -7.15       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1899        |
# |    policy_loss        | 34.7        |
# |    reward             | -0.56567776 |
# |    std                | 1.01        |
# |    value_loss         | 32.9        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 349      |
# |    iterations         | 2000     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -7.15    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1999     |
# |    policy_loss        | 43.8     |
# |    reward             | -9.05324 |
# |    std                | 1.01     |
# |    value_loss         | 47.5     |
# ------------------------------------
# ======A2C Validation from:  2021-06-04 to  2021-09-02
# A2C Sharpe Ratio:  0.547336259353026
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_252_29
# ----------------------------------
# | time/              |           |
# |    fps             | 423       |
# |    iterations      | 1         |
# |    time_elapsed    | 4         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 0.5788279 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 398         |
# ...
# | train/                |            |
# |    entropy_loss       | -7.25      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 299        |
# |    policy_loss        | -9.6       |
# |    reward             | -0.5807956 |
# |    std                | 1.03       |
# |    value_loss         | 2.32       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 350       |
# |    iterations         | 400       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -7.23     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 399       |
# |    policy_loss        | -12.2     |
# |    reward             | 1.5659848 |
# |    std                | 1.03      |
# |    value_loss         | 4.04      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 340        |
# |    iterations         | 500        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -7.22      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 499        |
# |    policy_loss        | -19.2      |
# |    reward             | -2.9425895 |
# |    std                | 1.03       |
# |    value_loss         | 35.5       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 341       |
# |    iterations         | 600       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -7.24     |
# |    explained_variance | 0.551     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 599       |
# |    policy_loss        | 2.18      |
# |    reward             | 0.3163651 |
# |    std                | 1.03      |
# |    value_loss         | 0.384     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 343         |
# |    iterations         | 700         |
# |    time_elapsed       | 10          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -7.24       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 699         |
# |    policy_loss        | 0.491       |
# |    reward             | -0.44205987 |
# |    std                | 1.03        |
# |    value_loss         | 16.8        |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 344           |
# |    iterations         | 800           |
# |    time_elapsed       | 11            |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -7.25         |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0005        |
# |    n_updates          | 799           |
# |    policy_loss        | -1.07         |
# |    reward             | 0.00073615764 |
# |    std                | 1.03          |
# |    value_loss         | 0.0183        |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 347         |
# |    iterations         | 900         |
# |    time_elapsed       | 12          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -7.32       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 899         |
# |    policy_loss        | 0.0983      |
# |    reward             | 0.011045644 |
# |    std                | 1.05        |
# |    value_loss         | 0.000286    |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 349          |
# |    iterations         | 1000         |
# |    time_elapsed       | 14           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -7.41        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0005       |
# |    n_updates          | 999          |
# |    policy_loss        | 0.111        |
# |    reward             | 0.0024169993 |
# |    std                | 1.07         |
# |    value_loss         | 0.000247     |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 351         |
# |    iterations         | 1100        |
# |    time_elapsed       | 15          |
# |    total_timesteps    | 5500        |
# | train/                |             |
# |    entropy_loss       | -7.56       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1099        |
# |    policy_loss        | 0.0231      |
# |    reward             | 0.014906782 |
# |    std                | 1.1         |
# |    value_loss         | 2.49e-05    |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 352           |
# |    iterations         | 1200          |
# |    time_elapsed       | 17            |
# |    total_timesteps    | 6000          |
# | train/                |               |
# |    entropy_loss       | -7.69         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0005        |
# |    n_updates          | 1199          |
# |    policy_loss        | 0.0716        |
# |    reward             | -0.0007626233 |
# |    std                | 1.13          |
# |    value_loss         | 0.000281      |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 354        |
# |    iterations         | 1300       |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -7.82      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1299       |
# |    policy_loss        | -0.129     |
# |    reward             | 0.00816529 |
# |    std                | 1.16       |
# |    value_loss         | 0.000318   |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 355         |
# |    iterations         | 1400        |
# |    time_elapsed       | 19          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -7.91       |
# |    explained_variance | 1.79e-07    |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1399        |
# |    policy_loss        | 3.78        |
# |    reward             | 0.113221705 |
# |    std                | 1.18        |
# |    value_loss         | 0.262       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 355         |
# |    iterations         | 1500        |
# |    time_elapsed       | 21          |
# |    total_timesteps    | 7500        |
# | train/                |             |
# |    entropy_loss       | -7.92       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1499        |
# |    policy_loss        | 0.833       |
# |    reward             | -0.07957911 |
# |    std                | 1.18        |
# |    value_loss         | 0.0118      |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 356          |
# |    iterations         | 1600         |
# |    time_elapsed       | 22           |
# |    total_timesteps    | 8000         |
# | train/                |              |
# |    entropy_loss       | -7.94        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0005       |
# |    n_updates          | 1599         |
# |    policy_loss        | -0.488       |
# |    reward             | 0.0044376426 |
# |    std                | 1.18         |
# |    value_loss         | 0.00395      |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 356           |
# |    iterations         | 1700          |
# |    time_elapsed       | 23            |
# |    total_timesteps    | 8500          |
# | train/                |               |
# |    entropy_loss       | -8.01         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0005        |
# |    n_updates          | 1699          |
# |    policy_loss        | -0.124        |
# |    reward             | -0.0053325812 |
# |    std                | 1.2           |
# |    value_loss         | 0.00028       |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 357          |
# |    iterations         | 1800         |
# |    time_elapsed       | 25           |
# |    total_timesteps    | 9000         |
# | train/                |              |
# |    entropy_loss       | -8.11        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0005       |
# |    n_updates          | 1799         |
# |    policy_loss        | 0.22         |
# |    reward             | -0.005181948 |
# |    std                | 1.23         |
# |    value_loss         | 0.000808     |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 358        |
# |    iterations         | 1900       |
# |    time_elapsed       | 26         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -8.21      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1899       |
# |    policy_loss        | 0.866      |
# |    reward             | 0.06949183 |
# |    std                | 1.25       |
# |    value_loss         | 0.0117     |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 359         |
# |    iterations         | 2000        |
# |    time_elapsed       | 27          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -8.3        |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1999        |
# |    policy_loss        | -0.349      |
# |    reward             | 0.037916135 |
# |    std                | 1.27        |
# |    value_loss         | 0.101       |
# ---------------------------------------
# ======A2C Validation from:  2021-09-02 to  2021-12-02
# A2C Sharpe Ratio:  0.2520580102573898
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_315_26
# -----------------------------------
# | time/              |            |
# |    fps             | 423        |
# |    iterations      | 1          |
# |    time_elapsed    | 4          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.31107134 |
# -----------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 400           |
# |    iterations           | 2             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.0029373865  |
# |    clip_fraction        | 0.0469        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.11         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.133         |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00257      |
# |    reward               | -0.0026441934 |
# |    std                  | 1             |
# |    value_loss           | 0.391         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 395          |
# |    iterations           | 3            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0046646055 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.11        |
# |    explained_variance   | 0.011        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 22.2         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00307     |
# |    reward               | 0.1679066    |
# |    std                  | 1            |
# |    value_loss           | 56.5         |
# ------------------------------------------
# day: 3943, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 6697144.58
# total_reward: 5697144.58
# total_cost: 59981.04
# total_trades: 19081
# Sharpe: 0.689
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 4            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0026589269 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.12        |
# |    explained_variance   | 0.268        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.698        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | 0.00106      |
# |    reward               | 0.22589558   |
# |    std                  | 1.01         |
# |    value_loss           | 2.11         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 5           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006284542 |
# |    clip_fraction        | 0.0244      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.14       |
# |    explained_variance   | 0.0106      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 159         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00424    |
# |    reward               | 2.7104726   |
# |    std                  | 1.01        |
# |    value_loss           | 287         |
# -----------------------------------------
# ======PPO Validation from:  2021-09-02 to  2021-12-02
# PPO Sharpe Ratio:  0.12297945719657871
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_315_24
# ======DDPG Validation from:  2021-09-02 to  2021-12-02
# ======Best Model Retraining from:  2006-01-01 to  2021-12-02
# ======Trading from:  2021-12-02 to  2022-03-04
# Ensemble Strategy took:  10.782266000906626  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2020-12-02  2021-03-05       DDPG  -0.021281   -0.05341    0.002298
# 1  189  2021-03-05  2021-06-04        A2C   0.170426  -0.145553   -0.119032
# 2  252  2021-06-04  2021-09-02        A2C   0.547336    0.35878    0.427609
# 3  315  2021-09-02  2021-12-02       DDPG   0.252058   0.122979    0.262621

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > val_test_start)&(processed.date <= val_test_end)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  0.6356032556564686

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2021-03-05           NaN  2021-03-05
# 1   9.967626e+05  2021-03-08     -0.003237  2021-03-08
# 2   1.001184e+06  2021-03-09      0.004436  2021-03-09
# 3   1.000395e+06  2021-03-10     -0.000788  2021-03-10
# 4   1.009840e+06  2021-03-11      0.009441  2021-03-11

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.149529
# Cumulative returns     0.149529
# Annual volatility      0.283010
# Sharpe ratio           0.635603
# Calmar ratio           0.579363
# Stability              0.600813
# Max drawdown          -0.258093
# Omega ratio            1.115852
# Sortino ratio          0.912679
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.012381
# Daily value at risk   -0.034942
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.076357
# Cumulative returns     0.076042
# Annual volatility      0.128444
# Sharpe ratio           0.639265
# Calmar ratio           0.766080
# Stability              0.396026
# Max drawdown          -0.099672
# Omega ratio            1.110797
# Sortino ratio          0.907534
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.952372
# Daily value at risk   -0.015857
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========") # too unstable, performance change too much
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-03-05</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-03-03</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>14.953%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>14.953%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>28.301%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.64</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.58</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.60</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-25.809%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.12</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.91</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.01</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.494%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.11</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.90</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>25.81</td>
#       <td>2021-11-19</td>
#       <td>2022-02-23</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>12.40</td>
#       <td>2021-04-13</td>
#       <td>2021-05-12</td>
#       <td>2021-07-06</td>
#       <td>61</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8.23</td>
#       <td>2021-09-07</td>
#       <td>2021-10-04</td>
#       <td>2021-10-21</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.71</td>
#       <td>2021-07-06</td>
#       <td>2021-08-18</td>
#       <td>2021-08-23</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.95</td>
#       <td>2021-03-23</td>
#       <td>2021-03-25</td>
#       <td>2021-04-01</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.07%</td>
#       <td>-6.47%</td>
#       <td>5.95%</td>
#     </tr>
#   </tbody>
# </table>
