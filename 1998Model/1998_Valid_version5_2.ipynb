# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy - Modified: tech indicator
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# install finrl library
# !git clone https://github.com/AI4Finance-LLC/FinRL-Library.git

# %%
import sys
sys.path.append("FinRL-Library")

# %%
# install packages
# !pip install yfinance

# %%
# !pip install stockstats

# %%
# !pip install git+https://github.com/quantopian/pyfolio

# %%
# ## install finrl library
#!pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.apps import config
from finrl.finrl_meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.finrl_meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.finrl_meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.drl_agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
# from config.py start_date is a string
config.START_DATE
# Out:
# '2009-01-01'

# %%
print(config.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
# I changed the end datae to yesterday, original date is 2021-07-06
df = YahooDownloader(start_date = '1998-01-01',
                     end_date = '2022-03-21',
                     ticker_list = config.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (172926, 8)

# %%
df.head()
# Out:
#          date       open       high        low      close       volume   tic  \
# 0  1998-01-02   0.121652   0.145089   0.120536   0.124236  718110400.0  AAPL
# 1  1998-01-02  13.515625  13.531250  13.343750  10.338571    4234800.0  AMGN
# 2  1998-01-02  25.967234  25.967234  25.766644  18.672760    3085685.0   AXP
# 3  1998-01-02  48.937500  49.812500  48.125000  30.740921    2761300.0    BA
# 4  1998-01-02  24.250000  24.500000  24.250000  12.989574    1345000.0   CAT
#
#    day
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4

# %%
df.tail()
# Out:
#               date        open        high         low       close  \
# 172921  2022-03-18  508.739990  510.679993  501.559998  506.119995
# 172922  2022-03-18  211.699997  219.259995  210.289993  219.110001
# 172923  2022-03-18   52.119999   52.290001   50.799999   50.799999
# 172924  2022-03-18   47.349998   47.450001   46.470001   47.360001
# 172925  2022-03-18  145.179993  145.570007  144.110001  145.440002
#
#             volume  tic  day
# 172921   5059000.0  UNH    4
# 172922  14608100.0    V    4
# 172923  70348600.0   VZ    4
# 172924  11368000.0  WBA    4
# 172925  10407600.0  WMT    4

# %%
df.shape
# Out:
# (172926, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close       volume   tic  \
# 0  1998-01-02   0.121652   0.145089   0.120536   0.124236  718110400.0  AAPL
# 1  1998-01-02  13.515625  13.531250  13.343750  10.338571    4234800.0  AMGN
# 2  1998-01-02  25.967234  25.967234  25.766644  18.672760    3085685.0   AXP
# 3  1998-01-02  48.937500  49.812500  48.125000  30.740921    2761300.0    BA
# 4  1998-01-02  24.250000  24.500000  24.250000  12.989574    1345000.0   CAT
#
#    day
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4

# %%
len(df.tic.unique())
# Out:
# 30

# %%
df.tic.value_counts()
# Out:
# AAPL    6093
# KO      6093
# WMT     6093
# WBA     6093
# VZ      6093
# UNH     6093
# TRV     6093
# PG      6093
# NKE     6093
# MSFT    6093
# MRK     6093
# MMM     6093
# AMGN    6093
# MCD     6093
# JPM     6093
# JNJ     6093
# INTC    6093
# IBM     6093
# HON     6093
# HD      6093
# DIS     6093
# CVX     6093
# CSCO    6093
# CAT     6093
# BA      6093
# AXP     6093
# GS      5758
# CRM     4467
# V       3526
# DOW      757
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
# added indicators
tech_indicators = [    #"boll_ub", "boll_lb", # this two are new
'macd',
 'rsi_30',
 'cci_30',
 'dx_30']

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = tech_indicators,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.sample(5)
# Out:
#               date        open        high         low      close     volume  \
# 107958  2014-07-07  130.440002  130.639999  130.020004  92.967049  3660000.0
# 36304   2003-07-24   32.160000   32.470001   31.459999  20.522646  7095400.0
# 34614   2003-04-22   27.219999   27.750000   27.080000  17.992540  9557200.0
# 78027   2009-12-07   57.320000   57.450001   56.330002  43.303642  6061300.0
# 136441  2018-11-07   76.940002   78.230003   76.570000  75.457558  5403900.0
#
#          tic  day      macd     rsi_30      cci_30      dx_30  turbulence
# 107958   CVX    0  1.201944  62.718098   61.133396  21.201198   20.998395
# 36304     HD    3 -0.055730  50.053931 -144.271684  13.390456   13.377719
# 34614     HD    1  0.618455  61.890209  120.252959  41.804052   15.473996
# 78027   AMGN    0  0.128463  48.968008   82.495172   1.369783   12.941842
# 136441   NKE    2 -0.698476  50.143149    4.703771   4.792758   30.265696

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(tech_indicators)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 26, State Space: 157

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": tech_indicators,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)
train_start = '1998-01-01'
train_end = '2018-12-01' #original is 2020-4-1
val_test_start = '2018-12-01' #original is 2020-4-1
val_test_end = '2022-03-21'#original is 2021-7-06

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(train_start,train_end),
                 val_test_period=(val_test_start,val_test_end),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.01,
                    'learning_rate': 0.0005
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 64
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 100_000,
                      "learning_rate": 0.000005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 30_000, 
                 'ppo' : 100_000, 
                 'ddpg' : 10_000
                 }


timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  164.4792476874577
# ======Model training from:  1998-01-01 to  2018-12-03
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_126_26
# -------------------------------------
# | time/                 |           |
# |    fps                | 43        |
# |    iterations         | 100       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.103    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 99        |
# |    policy_loss        | 102       |
# |    reward             | 0.6890273 |
# |    std                | 1.01      |
# |    value_loss         | 17.2      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 57        |
# |    iterations         | 200       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 199       |
# |    policy_loss        | 93.9      |
# |    reward             | 0.9469804 |
# |    std                | 1.01      |
# |    value_loss         | 9.13      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 65         |
# |    iterations         | 300        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | -0.0803    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 299        |
# |    policy_loss        | 22.7       |
# |    reward             | 0.20925684 |
# |    std                | 1.01       |
# |    value_loss         | 0.713      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 70        |
# |    iterations         | 400       |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.0206   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 399       |
# |    policy_loss        | -108      |
# |    reward             | 0.6345918 |
# |    std                | 1.01      |
# |    value_loss         | 10.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 73        |
# |    iterations         | 500       |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | 0.0716    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 499       |
# |    policy_loss        | -19       |
# |    reward             | -5.935928 |
# |    std                | 1.01      |
# |    value_loss         | 2.98      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 75        |
# |    iterations         | 600       |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 599       |
# |    policy_loss        | -99.9     |
# |    reward             | 1.0162686 |
# |    std                | 1.01      |
# |    value_loss         | 8.07      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 77         |
# |    iterations         | 700        |
# |    time_elapsed       | 45         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 2.38e-07   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 699        |
# |    policy_loss        | -263       |
# |    reward             | -0.5499368 |
# |    std                | 1.01       |
# |    value_loss         | 57         |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 78        |
# |    iterations         | 800       |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.192    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 799       |
# |    policy_loss        | 113       |
# |    reward             | 0.5328286 |
# |    std                | 1.01      |
# |    value_loss         | 13.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 79        |
# |    iterations         | 900       |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.116    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 899       |
# |    policy_loss        | -302      |
# |    reward             | 1.0515356 |
# |    std                | 1.01      |
# |    value_loss         | 76.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 79        |
# |    iterations         | 1000      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.24     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 999       |
# |    policy_loss        | -34.3     |
# |    reward             | 1.7278135 |
# |    std                | 1.01      |
# |    value_loss         | 3.92      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 80        |
# |    iterations         | 1100      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.285    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1099      |
# |    policy_loss        | -89.3     |
# |    reward             | -0.403097 |
# |    std                | 1.01      |
# |    value_loss         | 6.85      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 80         |
# |    iterations         | 1200       |
# |    time_elapsed       | 74         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1199       |
# |    policy_loss        | -10.5      |
# |    reward             | -0.7282551 |
# |    std                | 1.01       |
# |    value_loss         | 1.05       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 81         |
# |    iterations         | 1300       |
# |    time_elapsed       | 79         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | -0.277     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1299       |
# |    policy_loss        | 68.4       |
# |    reward             | -1.0639689 |
# |    std                | 1.01       |
# |    value_loss         | 9.51       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 81          |
# |    iterations         | 1400        |
# |    time_elapsed       | 85          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -37.2       |
# |    explained_variance | -0.171      |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1399        |
# |    policy_loss        | -84         |
# |    reward             | -0.46193358 |
# |    std                | 1.01        |
# |    value_loss         | 5.76        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 1500       |
# |    time_elapsed       | 91         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | -0.00363   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1499       |
# |    policy_loss        | 20.9       |
# |    reward             | 0.12908585 |
# |    std                | 1.01       |
# |    value_loss         | 0.314      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 82        |
# |    iterations         | 1600      |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1599      |
# |    policy_loss        | -164      |
# |    reward             | -3.601182 |
# |    std                | 1.01      |
# |    value_loss         | 34.5      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 82          |
# |    iterations         | 1700        |
# |    time_elapsed       | 102         |
# |    total_timesteps    | 8500        |
# | train/                |             |
# |    entropy_loss       | -37.3       |
# |    explained_variance | 0.0235      |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1699        |
# |    policy_loss        | 211         |
# |    reward             | -0.10068894 |
# |    std                | 1.01        |
# |    value_loss         | 32          |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 83         |
# |    iterations         | 1800       |
# |    time_elapsed       | 108        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -37.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1799       |
# |    policy_loss        | -102       |
# |    reward             | -4.7449417 |
# |    std                | 1.01       |
# |    value_loss         | 7.89       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 83          |
# |    iterations         | 1900        |
# |    time_elapsed       | 113         |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -37.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1899        |
# |    policy_loss        | 355         |
# |    reward             | -0.26330838 |
# |    std                | 1.01        |
# |    value_loss         | 175         |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 83        |
# |    iterations         | 2000      |
# |    time_elapsed       | 119       |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1999      |
# |    policy_loss        | 3.12      |
# |    reward             | 3.1078207 |
# |    std                | 1.01      |
# |    value_loss         | 5.98      |
# -------------------------------------
# ======A2C Validation from:  2018-12-03 to  2019-03-07
# A2C Sharpe Ratio:  0.07789929148719921
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_24
# ----------------------------------
# | time/              |           |
# |    fps             | 89        |
# |    iterations      | 1         |
# |    time_elapsed    | 22        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 0.1917876 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 2           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015297119 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.9       |
# |    explained_variance   | -0.0201     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.97        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0155     |
# |    reward               | 1.7690643   |
# |    std                  | 1           |
# |    value_loss           | 5.85        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 89         |
# |    iterations           | 3          |
# |    time_elapsed         | 68         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01495434 |
# |    clip_fraction        | 0.167      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -37        |
# |    explained_variance   | -0.0254    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 12.1       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0177    |
# |    reward               | -2.1863103 |
# |    std                  | 1          |
# |    value_loss           | 19.8       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 4           |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014470573 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37         |
# |    explained_variance   | 0.016       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0141     |
# |    reward               | 0.024184385 |
# |    std                  | 1.01        |
# |    value_loss           | 38.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 5           |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018872086 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37         |
# |    explained_variance   | -0.00359    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.91        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0242     |
# |    reward               | -0.86722654 |
# |    std                  | 1.01        |
# |    value_loss           | 10.9        |
# -----------------------------------------
# ======PPO Validation from:  2018-12-03 to  2019-03-07
# PPO Sharpe Ratio:  0.06417981088584192
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_126_18
# day: 5263, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 8772195.08
# total_reward: 7772195.08
# total_cost: 4011.94
# total_trades: 63591
# Sharpe: 0.613
# =================================
# ======DDPG Validation from:  2018-12-03 to  2019-03-07
# ======Best Model Retraining from:  1998-01-01 to  2019-03-07
# ======Trading from:  2019-03-07 to  2019-06-06
# ============================================
# turbulence_threshold:  164.4792476874577
# ======Model training from:  1998-01-01 to  2019-03-07
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_189_19
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 100       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | -0.12     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 99        |
# |    policy_loss        | -29.3     |
# |    reward             | 1.4865545 |
# |    std                | 1.01      |
# |    value_loss         | 0.889     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 200        |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | -2.38e-07  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 199        |
# |    policy_loss        | 15.7       |
# |    reward             | 0.06810156 |
# |    std                | 1.01       |
# |    value_loss         | 1.95       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 300        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 299        |
# |    policy_loss        | 23.3       |
# |    reward             | -0.7619797 |
# |    std                | 1.01       |
# |    value_loss         | 0.636      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 400        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0.0162     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 399        |
# |    policy_loss        | -103       |
# |    reward             | 0.14118421 |
# |    std                | 1.01       |
# |    value_loss         | 7.94       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 500        |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 499        |
# |    policy_loss        | 79.5       |
# |    reward             | -6.0090594 |
# |    std                | 1.01       |
# |    value_loss         | 9.62       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 600        |
# |    time_elapsed       | 34         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 599        |
# |    policy_loss        | -84.5      |
# |    reward             | -0.8599852 |
# |    std                | 1.01       |
# |    value_loss         | 6.43       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 87          |
# |    iterations         | 700         |
# |    time_elapsed       | 40          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -37.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 699         |
# |    policy_loss        | -207        |
# |    reward             | -0.15534008 |
# |    std                | 1.01        |
# |    value_loss         | 36.3        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 87          |
# |    iterations         | 800         |
# |    time_elapsed       | 45          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -37.1       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 799         |
# |    policy_loss        | 49.5        |
# |    reward             | 0.095296785 |
# |    std                | 1.01        |
# |    value_loss         | 7.37        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 900        |
# |    time_elapsed       | 51         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 899        |
# |    policy_loss        | -248       |
# |    reward             | -0.8481506 |
# |    std                | 1.01       |
# |    value_loss         | 54.9       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 87       |
# |    iterations         | 1000     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -37.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 999      |
# |    policy_loss        | 66.7     |
# |    reward             | 1.277241 |
# |    std                | 1.01     |
# |    value_loss         | 6.62     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 87       |
# |    iterations         | 1100     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -37.2    |
# |    explained_variance | 0.0513   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1099     |
# |    policy_loss        | -114     |
# |    reward             | -3.16452 |
# |    std                | 1.01     |
# |    value_loss         | 28.1     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 87       |
# |    iterations         | 1200     |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -37.2    |
# |    explained_variance | -0.648   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1199     |
# |    policy_loss        | 10.2     |
# |    reward             | 0.364151 |
# |    std                | 1.01     |
# |    value_loss         | 0.981    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1300      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | -0.119    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1299      |
# |    policy_loss        | -61.7     |
# |    reward             | 1.4467568 |
# |    std                | 1.01      |
# |    value_loss         | 3.2       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1400       |
# |    time_elapsed       | 80         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1399       |
# |    policy_loss        | -10.5      |
# |    reward             | -1.1541542 |
# |    std                | 1.01       |
# |    value_loss         | 0.422      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1500       |
# |    time_elapsed       | 85         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | -0.191     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1499       |
# |    policy_loss        | 85.3       |
# |    reward             | -2.0529034 |
# |    std                | 1.01       |
# |    value_loss         | 6.66       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1600       |
# |    time_elapsed       | 91         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1599       |
# |    policy_loss        | 130        |
# |    reward             | -1.1505817 |
# |    std                | 1.01       |
# |    value_loss         | 23.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1700      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | 0.0218    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1699      |
# |    policy_loss        | 27        |
# |    reward             | 0.6763084 |
# |    std                | 1.01      |
# |    value_loss         | 4.34      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1800      |
# |    time_elapsed       | 102       |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | 0.0712    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1799      |
# |    policy_loss        | 136       |
# |    reward             | 1.8728249 |
# |    std                | 1.01      |
# |    value_loss         | 30.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1900       |
# |    time_elapsed       | 108        |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | -2.38e-07  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1899       |
# |    policy_loss        | -133       |
# |    reward             | -7.6653156 |
# |    std                | 1.01       |
# |    value_loss         | 14.7       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 87       |
# |    iterations         | 2000     |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -37.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.796    |
# |    reward             | 3.375911 |
# |    std                | 1.01     |
# |    value_loss         | 2.45     |
# ------------------------------------
# ======A2C Validation from:  2019-03-07 to  2019-06-06
# A2C Sharpe Ratio:  0.04733537952584217
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_19
# -----------------------------------
# | time/              |            |
# |    fps             | 90         |
# |    iterations      | 1          |
# |    time_elapsed    | 22         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.13393559 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 2           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016910562 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37         |
# |    explained_variance   | 0.00616     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.58        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0233     |
# |    reward               | 1.3479342   |
# |    std                  | 1           |
# |    value_loss           | 6.51        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 3           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014099314 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37         |
# |    explained_variance   | 0.0164      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0221     |
# |    reward               | 0.92001617  |
# |    std                  | 1.01        |
# |    value_loss           | 22.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 88         |
# |    iterations           | 4          |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01497739 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -37.1      |
# |    explained_variance   | 0.0714     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 90.6       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0162    |
# |    reward               | 3.1813035  |
# |    std                  | 1.01       |
# |    value_loss           | 129        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 5           |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.021588918 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.1       |
# |    explained_variance   | 0.0562      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.43        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0181     |
# |    reward               | 0.84046006  |
# |    std                  | 1.01        |
# |    value_loss           | 11.5        |
# -----------------------------------------
# ======PPO Validation from:  2019-03-07 to  2019-06-06
# PPO Sharpe Ratio:  -0.20728432689057727
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_189_18
# day: 5326, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 8953692.79
# total_reward: 7953692.79
# total_cost: 4039.30
# total_trades: 75913
# Sharpe: 0.642
# =================================
# ======DDPG Validation from:  2019-03-07 to  2019-06-06
# ======Best Model Retraining from:  1998-01-01 to  2019-06-06
# ======Trading from:  2019-06-06 to  2019-09-05
# ============================================
# turbulence_threshold:  164.4792476874577
# ======Model training from:  1998-01-01 to  2019-06-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_252_18
# -------------------------------------
# | time/                 |           |
# |    fps                | 82        |
# |    iterations         | 100       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -36.9     |
# |    explained_variance | -0.484    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 99        |
# |    policy_loss        | -23.9     |
# |    reward             | 0.8568061 |
# |    std                | 1         |
# |    value_loss         | 1         |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 84        |
# |    iterations         | 200       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -36.9     |
# |    explained_variance | -0.00774  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 199       |
# |    policy_loss        | 39.1      |
# |    reward             | 0.6502968 |
# |    std                | 1         |
# |    value_loss         | 2.01      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 84         |
# |    iterations         | 300        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | -0.66      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 299        |
# |    policy_loss        | 25.4       |
# |    reward             | -0.2672717 |
# |    std                | 1          |
# |    value_loss         | 0.806      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 84        |
# |    iterations         | 400       |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -36.9     |
# |    explained_variance | -0.148    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 399       |
# |    policy_loss        | -50.3     |
# |    reward             | 1.8720361 |
# |    std                | 1         |
# |    value_loss         | 2.28      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 500       |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 499       |
# |    policy_loss        | -30.6     |
# |    reward             | -7.109861 |
# |    std                | 1         |
# |    value_loss         | 10.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 600        |
# |    time_elapsed       | 35         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | -0.102     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 599        |
# |    policy_loss        | -84.6      |
# |    reward             | 0.48926237 |
# |    std                | 1          |
# |    value_loss         | 6.37       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 700        |
# |    time_elapsed       | 41         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | 0.0826     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 699        |
# |    policy_loss        | -274       |
# |    reward             | -0.7297912 |
# |    std                | 1.01       |
# |    value_loss         | 68.9       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 800       |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 799       |
# |    policy_loss        | 167       |
# |    reward             | 2.3267422 |
# |    std                | 1         |
# |    value_loss         | 27.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 900       |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | 0.0779    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 899       |
# |    policy_loss        | -325      |
# |    reward             | 1.1593326 |
# |    std                | 1         |
# |    value_loss         | 80.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 84         |
# |    iterations         | 1000       |
# |    time_elapsed       | 58         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 999        |
# |    policy_loss        | -33.3      |
# |    reward             | -1.3452697 |
# |    std                | 1          |
# |    value_loss         | 5.73       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 84         |
# |    iterations         | 1100       |
# |    time_elapsed       | 64         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -36.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1099       |
# |    policy_loss        | 9.93       |
# |    reward             | -1.1969507 |
# |    std                | 1          |
# |    value_loss         | 0.274      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 84          |
# |    iterations         | 1200        |
# |    time_elapsed       | 70          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -36.9       |
# |    explained_variance | 0.00113     |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1199        |
# |    policy_loss        | 35.3        |
# |    reward             | -0.71154755 |
# |    std                | 1           |
# |    value_loss         | 2.05        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 84       |
# |    iterations         | 1300     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -36.9    |
# |    explained_variance | 0.00541  |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1299     |
# |    policy_loss        | -123     |
# |    reward             | 1.750282 |
# |    std                | 1        |
# |    value_loss         | 11.9     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 84         |
# |    iterations         | 1400       |
# |    time_elapsed       | 82         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -36.9      |
# |    explained_variance | 0.0293     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1399       |
# |    policy_loss        | -11.9      |
# |    reward             | -0.8488149 |
# |    std                | 1          |
# |    value_loss         | 0.686      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 84        |
# |    iterations         | 1500      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | -0.13     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1499      |
# |    policy_loss        | -88.2     |
# |    reward             | 1.3372785 |
# |    std                | 1         |
# |    value_loss         | 6.91      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 84         |
# |    iterations         | 1600       |
# |    time_elapsed       | 94         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | 0.00276    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1599       |
# |    policy_loss        | 19.8       |
# |    reward             | -1.8909411 |
# |    std                | 1          |
# |    value_loss         | 1.59       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 1700      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | -0.0854   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1699      |
# |    policy_loss        | -257      |
# |    reward             | -2.371018 |
# |    std                | 1         |
# |    value_loss         | 63.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 1800       |
# |    time_elapsed       | 105        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0.237      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1799       |
# |    policy_loss        | -45.6      |
# |    reward             | -1.8326749 |
# |    std                | 1.01       |
# |    value_loss         | 2.41       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 1900       |
# |    time_elapsed       | 111        |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0.0809     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1899       |
# |    policy_loss        | 159        |
# |    reward             | -2.3769252 |
# |    std                | 1.01       |
# |    value_loss         | 20.4       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 83         |
# |    iterations         | 2000       |
# |    time_elapsed       | 119        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | -0.027     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1999       |
# |    policy_loss        | -198       |
# |    reward             | -1.2239753 |
# |    std                | 1.01       |
# |    value_loss         | 32.8       |
# --------------------------------------
# ======A2C Validation from:  2019-06-06 to  2019-09-05
# A2C Sharpe Ratio:  0.01507975743518787
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_252_18
# ------------------------------------
# | time/              |             |
# |    fps             | 30          |
# |    iterations      | 1           |
# |    time_elapsed    | 66          |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | 0.059414957 |
# ------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 0           |
# |    iterations           | 2           |
# |    time_elapsed         | 7299        |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016731195 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# ...
# |    n_updates          | 199       |
# |    policy_loss        | 24.2      |
# |    reward             | 0.5500644 |
# |    std                | 1.01      |
# |    value_loss         | 0.767     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 79          |
# |    iterations         | 300         |
# |    time_elapsed       | 18          |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -37.1       |
# |    explained_variance | 0.727       |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 299         |
# |    policy_loss        | 19.8        |
# |    reward             | -0.18432075 |
# |    std                | 1.01        |
# |    value_loss         | 0.351       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 79         |
# |    iterations         | 400        |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 399        |
# |    policy_loss        | -14.2      |
# |    reward             | 0.66557425 |
# |    std                | 1.01       |
# |    value_loss         | 0.68       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 79         |
# |    iterations         | 500        |
# |    time_elapsed       | 31         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | -0.00482   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 499        |
# |    policy_loss        | -29.7      |
# |    reward             | -2.0551507 |
# |    std                | 1.01       |
# |    value_loss         | 1.41       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 79        |
# |    iterations         | 600       |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | -0.0312   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 599       |
# |    policy_loss        | -2.37     |
# |    reward             | 0.5398534 |
# |    std                | 1.01      |
# |    value_loss         | 1.74      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 79       |
# |    iterations         | 700      |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -37.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 699      |
# |    policy_loss        | -188     |
# |    reward             | 2.408305 |
# |    std                | 1.01     |
# |    value_loss         | 36.8     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 79         |
# |    iterations         | 800        |
# |    time_elapsed       | 50         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0.0863     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 799        |
# |    policy_loss        | 98.5       |
# |    reward             | 0.70294416 |
# |    std                | 1.01       |
# |    value_loss         | 10.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 79        |
# |    iterations         | 900       |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.424    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 899       |
# |    policy_loss        | -177      |
# |    reward             | 1.5947629 |
# |    std                | 1.01      |
# |    value_loss         | 26.4      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 79       |
# |    iterations         | 1000     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -37.1    |
# |    explained_variance | -1.51    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 999      |
# |    policy_loss        | 93.8     |
# |    reward             | 3.28995  |
# |    std                | 1.01     |
# |    value_loss         | 10.5     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 79         |
# |    iterations         | 1100       |
# |    time_elapsed       | 68         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 1.79e-07   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1099       |
# |    policy_loss        | 203        |
# |    reward             | -2.8040466 |
# |    std                | 1.01       |
# |    value_loss         | 45.6       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 79         |
# |    iterations         | 1200       |
# |    time_elapsed       | 75         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1199       |
# |    policy_loss        | 13.6       |
# |    reward             | 0.40875912 |
# |    std                | 1.01       |
# |    value_loss         | 0.149      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 79         |
# |    iterations         | 1300       |
# |    time_elapsed       | 81         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | -0.0104    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1299       |
# |    policy_loss        | -86        |
# |    reward             | 0.32973695 |
# |    std                | 1.01       |
# |    value_loss         | 11         |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 79        |
# |    iterations         | 1400      |
# |    time_elapsed       | 87        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | -0.0224   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1399      |
# |    policy_loss        | -107      |
# |    reward             | 0.6372782 |
# |    std                | 1.01      |
# |    value_loss         | 11.1      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 79        |
# |    iterations         | 1500      |
# |    time_elapsed       | 94        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | -1.41     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1499      |
# |    policy_loss        | 8.36      |
# |    reward             | 1.2010956 |
# |    std                | 1.01      |
# |    value_loss         | 0.248     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 79          |
# |    iterations         | 1600        |
# |    time_elapsed       | 100         |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -37.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1599        |
# |    policy_loss        | 43.7        |
# |    reward             | -0.03537118 |
# |    std                | 1.01        |
# |    value_loss         | 2.37        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 79        |
# |    iterations         | 1700      |
# |    time_elapsed       | 106       |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | 0.0678    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1699      |
# |    policy_loss        | -67.4     |
# |    reward             | 1.6901973 |
# |    std                | 1.01      |
# |    value_loss         | 5.19      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 79          |
# |    iterations         | 1800        |
# |    time_elapsed       | 112         |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -37.3       |
# |    explained_variance | -0.0901     |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1799        |
# |    policy_loss        | -18.2       |
# |    reward             | -0.95029247 |
# |    std                | 1.02        |
# |    value_loss         | 1.62        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 79          |
# |    iterations         | 1900        |
# |    time_elapsed       | 118         |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -37.3       |
# |    explained_variance | 0.00466     |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1899        |
# |    policy_loss        | 119         |
# |    reward             | -0.24934806 |
# |    std                | 1.02        |
# |    value_loss         | 15.8        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 79         |
# |    iterations         | 2000       |
# |    time_elapsed       | 125        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -37.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1999       |
# |    policy_loss        | -125       |
# |    reward             | -2.1558347 |
# |    std                | 1.02       |
# |    value_loss         | 13.7       |
# --------------------------------------
# ======A2C Validation from:  2021-09-03 to  2021-12-03
# A2C Sharpe Ratio:  -0.18678037330152822
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_819_2
# ------------------------------------
# | time/              |             |
# |    fps             | 82          |
# |    iterations      | 1           |
# |    time_elapsed    | 24          |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.08235595 |
# ------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 2           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015305942 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.9       |
# |    explained_variance   | 0.000868    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.24        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0225     |
# |    reward               | 1.3833772   |
# |    std                  | 1           |
# |    value_loss           | 6.09        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 3           |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016897237 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37         |
# |    explained_variance   | 0.00419     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0179     |
# |    reward               | -1.4297917  |
# |    std                  | 1           |
# |    value_loss           | 16.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 4           |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014434081 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37         |
# |    explained_variance   | 0.00948     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 44.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0173     |
# |    reward               | 0.39510235  |
# |    std                  | 1.01        |
# |    value_loss           | 197         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 5           |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.022141553 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.1       |
# |    explained_variance   | -0.0326     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.16        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0199     |
# |    reward               | -0.25179774 |
# |    std                  | 1.01        |
# |    value_loss           | 8.95        |
# -----------------------------------------
# ======PPO Validation from:  2021-09-03 to  2021-12-03
# PPO Sharpe Ratio:  -0.10454675241314346
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_819_2
# day: 5956, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 7069788.94
# total_reward: 6069788.94
# total_cost: 4160.54
# total_trades: 78566
# Sharpe: 0.550
# =================================
# ======DDPG Validation from:  2021-09-03 to  2021-12-03
# ======Best Model Retraining from:  1998-01-01 to  2021-12-03
# ======Trading from:  2021-12-03 to  2022-03-07
# Ensemble Strategy took:  528.596330344677  minutes

# %%
df_summary
# Out:
#    Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0   126  2018-12-03  2019-03-07       DDPG   0.077899    0.06418    0.158199
# 1   189  2019-03-07  2019-06-06        A2C   0.047335  -0.207284   -0.124509
# 2   252  2019-06-06  2019-09-05        A2C    0.01508  -0.125493    0.009661
# 3   315  2019-09-05  2019-12-04       DDPG   -0.09932   0.060877    0.259066
# 4   378  2019-12-04  2020-03-06        A2C  -0.111448  -0.245092   -0.273756
# 5   441  2020-03-06  2020-06-05        PPO   0.188365   0.200343    0.098074
# 6   504  2020-06-05  2020-09-03        A2C   0.528295   0.317706    0.102684
# 7   567  2020-09-03  2020-12-03       DDPG   0.159512   0.211333    0.219439
# 8   630  2020-12-03  2021-03-08       DDPG   0.096755   0.140252    0.182606
# 9   693  2021-03-08  2021-06-07       DDPG   0.233017   0.257057    0.350239
# 10  756  2021-06-07  2021-09-03        A2C   0.474828   0.156288    0.117378
# 11  819  2021-09-03  2021-12-03       DDPG   -0.18678  -0.104547    0.128524

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > val_test_start)&(processed.date <= val_test_end)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  0.8080127903232005

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2019-03-07           NaN  2019-03-07
# 1   9.996179e+05  2019-03-08     -0.000382  2019-03-08
# 2   1.000616e+06  2019-03-11      0.000999  2019-03-11
# 3   9.946874e+05  2019-03-12     -0.005925  2019-03-12
# 4   9.992789e+05  2019-03-13      0.004616  2019-03-13

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.122900
# Cumulative returns     0.415869
# Annual volatility      0.159449
# Sharpe ratio           0.808013
# Calmar ratio           0.719593
# Stability              0.794142
# Max drawdown          -0.170791
# Omega ratio            1.158822
# Sortino ratio          1.124166
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.926351
# Daily value at risk   -0.019577
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (755, 8)
# Annual return          0.098944
# Cumulative returns     0.326674
# Annual volatility      0.236083
# Sharpe ratio           0.519111
# Calmar ratio           0.266795
# Stability              0.693332
# Max drawdown          -0.370862
# Omega ratio            1.118903
# Sortino ratio          0.714557
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.950961
# Daily value at risk   -0.029257
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (755, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-03-07</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-03-04</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>36</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>12.29%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>41.587%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>15.945%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.81</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.72</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.79</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-17.079%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.16</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.12</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.958%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.08</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.45</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>17.08</td>
#       <td>2020-02-06</td>
#       <td>2020-05-13</td>
#       <td>2020-08-27</td>
#       <td>146</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>9.10</td>
#       <td>2019-04-05</td>
#       <td>2019-06-03</td>
#       <td>2020-01-09</td>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>7.98</td>
#       <td>2020-09-02</td>
#       <td>2020-10-30</td>
#       <td>2020-12-28</td>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>7.03</td>
#       <td>2022-01-07</td>
#       <td>2022-02-24</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.94</td>
#       <td>2021-04-16</td>
#       <td>2021-05-12</td>
#       <td>2021-06-10</td>
#       <td>40</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.05%</td>
#       <td>-6.65%</td>
#       <td>5.12%</td>
#     </tr>
#   </tbody>
# </table>
