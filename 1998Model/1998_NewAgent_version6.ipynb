# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy - Modified: tech indicator
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# install finrl library
# !git clone https://github.com/AI4Finance-LLC/FinRL-Library.git

# %%
import sys
sys.path.append("FinRL-Library")

# %%
# install packages
# !pip install yfinance

# %%
# !pip install stockstats

# %%
# !pip install git+https://github.com/quantopian/pyfolio

# %%
# ## install finrl library
#!pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.apps import config
from finrl.finrl_meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.finrl_meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.finrl_meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.drl_agents.stablebaselines3.models_modified import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
# from config.py start_date is a string
# config.START_DATE
# Out:
# '2009-01-01'

# %%
print(config.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
# I changed the end datae to yesterday, original date is 2021-07-06
df = YahooDownloader(start_date = '1998-01-01',
                     end_date = '2022-03-21',
                     ticker_list = config.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (172926, 8)

# %%
df.head()
# Out:
#          date       open       high        low      close       volume   tic  \
# 0  1998-01-02   0.121652   0.145089   0.120536   0.124236  718110400.0  AAPL
# 1  1998-01-02  13.515625  13.531250  13.343750  10.338572    4234800.0  AMGN
# 2  1998-01-02  25.967234  25.967234  25.766644  18.672760    3085685.0   AXP
# 3  1998-01-02  48.937500  49.812500  48.125000  30.740917    2761300.0    BA
# 4  1998-01-02  24.250000  24.500000  24.250000  12.989579    1345000.0   CAT
#
#    day
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4

# %%
df.tail()
# Out:
#               date        open        high         low       close  \
# 172921  2022-03-18  508.739990  510.679993  501.559998  506.119995
# 172922  2022-03-18  211.699997  219.259995  210.289993  219.110001
# 172923  2022-03-18   52.119999   52.290001   50.799999   50.799999
# 172924  2022-03-18   47.349998   47.450001   46.470001   47.360001
# 172925  2022-03-18  145.179993  145.570007  144.110001  145.440002
#
#             volume  tic  day
# 172921   5059000.0  UNH    4
# 172922  14608100.0    V    4
# 172923  70348600.0   VZ    4
# 172924  11368000.0  WBA    4
# 172925  10407600.0  WMT    4

# %%
df.shape
# Out:
# (172926, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close       volume   tic  \
# 0  1998-01-02   0.121652   0.145089   0.120536   0.124236  718110400.0  AAPL
# 1  1998-01-02  13.515625  13.531250  13.343750  10.338572    4234800.0  AMGN
# 2  1998-01-02  25.967234  25.967234  25.766644  18.672760    3085685.0   AXP
# 3  1998-01-02  48.937500  49.812500  48.125000  30.740917    2761300.0    BA
# 4  1998-01-02  24.250000  24.500000  24.250000  12.989579    1345000.0   CAT
#
#    day
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4

# %%
len(df.tic.unique())
# Out:
# 30

# %%
df.tic.value_counts()
# Out:
# AAPL    6093
# KO      6093
# WMT     6093
# WBA     6093
# VZ      6093
# UNH     6093
# TRV     6093
# PG      6093
# NKE     6093
# MSFT    6093
# MRK     6093
# MMM     6093
# AMGN    6093
# MCD     6093
# JPM     6093
# JNJ     6093
# INTC    6093
# IBM     6093
# HON     6093
# HD      6093
# DIS     6093
# CVX     6093
# CSCO    6093
# CAT     6093
# BA      6093
# AXP     6093
# GS      5758
# CRM     4467
# V       3526
# DOW      757
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
# added indicators
tech_indicators = [    #"boll_ub", "boll_lb", # this two are new
'macd',
 'rsi_30',
 'cci_30',
 'dx_30']

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = tech_indicators,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.sample(5)
# Out:
#               date        open        high         low       close  \
# 45028   2004-11-19   41.474998   41.575001   40.395000   33.729130
# 119729  2016-04-21   69.470001   69.680000   68.239998   60.021114
# 142450  2019-10-10  218.190002  224.130005  217.520004  215.586456
# 53572   2006-03-14   59.150002   59.400002   59.029999   37.292023
# 119614  2016-04-15   45.820000   46.160000   45.680000   37.941078
#
#             volume  tic  day      macd     rsi_30      cci_30      dx_30  \
# 45028    4417600.0  UNH    4  1.137585  65.069204  104.207582  26.051031
# 119729   6617600.0  WMT    3  0.450967  54.951490   51.738517  12.444195
# 142450   5252200.0  UNH    3 -3.228499  44.743406  -49.235483  35.884699
# 53572    7888100.0  JNJ    1  0.014066  50.621903  118.563480  13.673962
# 119614  13647800.0   KO    4  0.370669  58.382048   24.878267  10.114683
#
#         turbulence
# 45028    24.707585
# 119729  135.833440
# 142450   15.619845
# 53572    45.127186
# 119614   10.553970

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(tech_indicators)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 26, State Space: 157

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": tech_indicators,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)
train_start = '1998-01-01'
train_end = '2020-12-01' #original is 2020-4-1
val_test_start = '2020-12-01' #original is 2020-4-1
val_test_end = '2022-03-21'#original is 2021-7-06

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(train_start,train_end),
                 val_test_period=(val_test_start,val_test_end),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.01,
                    'learning_rate': 0.0005
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 64
                    }

TD3_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 100_000,
                      "learning_rate": 0.000005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 30_000, 
                 'ppo' : 100_000, 
                 'td3' : 10_000
                 }


timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'td3' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 TD3_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  182.44639520957034
# ======Model training from:  1998-01-01 to  2020-12-02
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_126_20
# -------------------------------------
# | time/                 |           |
# |    fps                | 27        |
# |    iterations         | 100       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | 0.234     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 99        |
# |    policy_loss        | -152      |
# |    reward             | 1.6783676 |
# |    std                | 1.01      |
# |    value_loss         | 15.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 37         |
# |    iterations         | 200        |
# |    time_elapsed       | 26         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | -0.409     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 199        |
# |    policy_loss        | 30.2       |
# |    reward             | 0.29764548 |
# |    std                | 1.01       |
# |    value_loss         | 1.55       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 41          |
# |    iterations         | 300         |
# |    time_elapsed       | 35          |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -37.2       |
# |    explained_variance | -0.584      |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 299         |
# |    policy_loss        | 58.5        |
# |    reward             | -0.02511535 |
# |    std                | 1.01        |
# |    value_loss         | 3.43        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 45         |
# |    iterations         | 400        |
# |    time_elapsed       | 44         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | 0.176      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 399        |
# |    policy_loss        | -12.7      |
# |    reward             | 0.47012275 |
# |    std                | 1.01       |
# |    value_loss         | 0.184      |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 47       |
# |    iterations         | 500      |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -37.1    |
# |    explained_variance | -0.245   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 499      |
# |    policy_loss        | -16.3    |
# |    reward             | -3.77644 |
# |    std                | 1.01     |
# |    value_loss         | 1.66     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 48          |
# |    iterations         | 600         |
# |    time_elapsed       | 61          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -37.1       |
# |    explained_variance | -0.0537     |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 599         |
# |    policy_loss        | -55         |
# |    reward             | 0.035343178 |
# |    std                | 1.01        |
# |    value_loss         | 2.89        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 49          |
# |    iterations         | 700         |
# |    time_elapsed       | 70          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -37.1       |
# |    explained_variance | -0.158      |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 699         |
# |    policy_loss        | -288        |
# |    reward             | 0.075190045 |
# |    std                | 1.01        |
# |    value_loss         | 70.8        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 50        |
# |    iterations         | 800       |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 799       |
# |    policy_loss        | 82        |
# |    reward             | 1.3376247 |
# |    std                | 1.01      |
# |    value_loss         | 7.38      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 51          |
# |    iterations         | 900         |
# |    time_elapsed       | 87          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -37.1       |
# |    explained_variance | -0.0321     |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 899         |
# |    policy_loss        | -305        |
# |    reward             | -0.43614838 |
# |    std                | 1.01        |
# |    value_loss         | 71.5        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 52         |
# |    iterations         | 1000       |
# |    time_elapsed       | 95         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | -0.14      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 999        |
# |    policy_loss        | 89.9       |
# |    reward             | 0.90926325 |
# |    std                | 1.01       |
# |    value_loss         | 7.81       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 52         |
# |    iterations         | 1100       |
# |    time_elapsed       | 104        |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | 0.15       |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1099       |
# |    policy_loss        | 146        |
# |    reward             | 0.29600245 |
# |    std                | 1.01       |
# |    value_loss         | 18.4       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 53        |
# |    iterations         | 1200      |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | -0.398    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1199      |
# |    policy_loss        | 18.7      |
# |    reward             | 2.3966582 |
# |    std                | 1.01      |
# |    value_loss         | 1.51      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 53        |
# |    iterations         | 1300      |
# |    time_elapsed       | 121       |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | -0.765    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1299      |
# |    policy_loss        | -46.1     |
# |    reward             | 0.7305144 |
# |    std                | 1.01      |
# |    value_loss         | 1.93      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 53        |
# |    iterations         | 1400      |
# |    time_elapsed       | 129       |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | -0.00885  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1399      |
# |    policy_loss        | 50.4      |
# |    reward             | 1.4777378 |
# |    std                | 1.01      |
# |    value_loss         | 2.64      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 54          |
# |    iterations         | 1500        |
# |    time_elapsed       | 138         |
# |    total_timesteps    | 7500        |
# | train/                |             |
# |    entropy_loss       | -37.1       |
# |    explained_variance | 0.0503      |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1499        |
# |    policy_loss        | -10.5       |
# |    reward             | -0.32500717 |
# |    std                | 1.01        |
# |    value_loss         | 0.278       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 54          |
# |    iterations         | 1600        |
# |    time_elapsed       | 147         |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -37.1       |
# |    explained_variance | -0.032      |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1599        |
# |    policy_loss        | -43.6       |
# |    reward             | -0.49158034 |
# |    std                | 1.01        |
# |    value_loss         | 1.87        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 54        |
# |    iterations         | 1700      |
# |    time_elapsed       | 155       |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1699      |
# |    policy_loss        | -33.1     |
# |    reward             | -3.329034 |
# |    std                | 1.01      |
# |    value_loss         | 5.27      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 54         |
# |    iterations         | 1800       |
# |    time_elapsed       | 164        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0.00334    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1799       |
# |    policy_loss        | -2.82      |
# |    reward             | -0.7927025 |
# |    std                | 1.01       |
# |    value_loss         | 0.342      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 55        |
# |    iterations         | 1900      |
# |    time_elapsed       | 172       |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.0253   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1899      |
# |    policy_loss        | -106      |
# |    reward             | -1.989212 |
# |    std                | 1.01      |
# |    value_loss         | 9.72      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 55         |
# |    iterations         | 2000       |
# |    time_elapsed       | 181        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0.0441     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1999       |
# |    policy_loss        | 133        |
# |    reward             | -1.0510658 |
# |    std                | 1.01       |
# |    value_loss         | 18.1       |
# --------------------------------------
# ======A2C Validation from:  2020-12-02 to  2021-03-05
# A2C Sharpe Ratio:  -0.021037435082574815
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_19
# -----------------------------------
# | time/              |            |
# |    fps             | 59         |
# |    iterations      | 1          |
# |    time_elapsed    | 34         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.09413981 |
# -----------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 2          |
# |    time_elapsed         | 69         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01850154 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -37        |
# |    explained_variance   | -0.02      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 1.46       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0221    |
# |    reward               | 1.0521336  |
# |    std                  | 1.01       |
# |    value_loss           | 5.94       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 3          |
# |    time_elapsed         | 104        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01691287 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -37.1      |
# |    explained_variance   | -0.0397    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 4.05       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0201    |
# |    reward               | 0.35345608 |
# |    std                  | 1.01       |
# |    value_loss           | 9.98       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 4           |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015265407 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.1       |
# |    explained_variance   | -0.00112    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 88.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.02       |
# |    reward               | 1.2214389   |
# |    std                  | 1.01        |
# |    value_loss           | 148         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 5           |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.022981912 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.2       |
# |    explained_variance   | 0.0311      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.08        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.024      |
# |    reward               | -1.2619712  |
# |    std                  | 1.01        |
# |    value_loss           | 7.13        |
# -----------------------------------------
# ======PPO Validation from:  2020-12-02 to  2021-03-05
# PPO Sharpe Ratio:  0.06936256672985561
# ======TD3 Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/td3/td3_126_1
# day: 5766, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 9067152.33
# total_reward: 8067152.33
# total_cost: 3728.44
# total_trades: 81578
# Sharpe: 0.590
# =================================
# ======TD3 Validation from:  2020-12-02 to  2021-03-05
# ======Best Model Retraining from:  1998-01-01 to  2021-03-05
# ======Trading from:  2021-03-05 to  2021-06-04
# ============================================
# turbulence_threshold:  182.44639520957034
# ======Model training from:  1998-01-01 to  2021-03-05
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_189_14
# ---------------------------------------
# | time/                 |             |
# |    fps                | 77          |
# |    iterations         | 100         |
# |    time_elapsed       | 6           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -36.9       |
# |    explained_variance | -0.00707    |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 99          |
# |    policy_loss        | 25.3        |
# |    reward             | -0.54351556 |
# |    std                | 1           |
# |    value_loss         | 7.69        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 79         |
# |    iterations         | 200        |
# |    time_elapsed       | 12         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -36.9      |
# |    explained_variance | 0.356      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 199        |
# |    policy_loss        | 15.3       |
# |    reward             | 0.46595204 |
# |    std                | 1          |
# |    value_loss         | 0.383      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 79          |
# |    iterations         | 300         |
# |    time_elapsed       | 18          |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -36.9       |
# |    explained_variance | 0.302       |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 299         |
# |    policy_loss        | 14.1        |
# |    reward             | -0.35577118 |
# |    std                | 1           |
# |    value_loss         | 0.209       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 79          |
# |    iterations         | 400         |
# |    time_elapsed       | 25          |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -37         |
# |    explained_variance | -2.38e-07   |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 399         |
# |    policy_loss        | -73.4       |
# |    reward             | 0.087000966 |
# |    std                | 1           |
# |    value_loss         | 3.77        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 80         |
# |    iterations         | 500        |
# |    time_elapsed       | 30         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | 0.0298     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 499        |
# |    policy_loss        | 31.5       |
# |    reward             | -2.6726213 |
# |    std                | 1          |
# |    value_loss         | 2.6        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 81         |
# |    iterations         | 600        |
# |    time_elapsed       | 36         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 599        |
# |    policy_loss        | 15.9       |
# |    reward             | 0.23466575 |
# |    std                | 1          |
# |    value_loss         | 3.18       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 81         |
# |    iterations         | 700        |
# |    time_elapsed       | 42         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 699        |
# |    policy_loss        | -167       |
# |    reward             | 0.35552317 |
# |    std                | 1          |
# |    value_loss         | 21.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 82        |
# |    iterations         | 800       |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 799       |
# |    policy_loss        | 170       |
# |    reward             | 2.5592341 |
# |    std                | 1         |
# |    value_loss         | 25.6      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 82        |
# |    iterations         | 900       |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | -0.0133   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 899       |
# |    policy_loss        | -774      |
# |    reward             | -2.509207 |
# |    std                | 1         |
# |    value_loss         | 473       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 1000       |
# |    time_elapsed       | 60         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 999        |
# |    policy_loss        | 70.2       |
# |    reward             | -4.8740416 |
# |    std                | 1          |
# |    value_loss         | 19.3       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 83          |
# |    iterations         | 1100        |
# |    time_elapsed       | 66          |
# |    total_timesteps    | 5500        |
# | train/                |             |
# |    entropy_loss       | -37         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1099        |
# |    policy_loss        | 442         |
# |    reward             | -0.90177286 |
# |    std                | 1           |
# |    value_loss         | 374         |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 83         |
# |    iterations         | 1200       |
# |    time_elapsed       | 71         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1199       |
# |    policy_loss        | -102       |
# |    reward             | -1.1166329 |
# |    std                | 1          |
# |    value_loss         | 7.88       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 83       |
# |    iterations         | 1300     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -37      |
# |    explained_variance | 0.0411   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1299     |
# |    policy_loss        | 93.8     |
# |    reward             | -2.40409 |
# |    std                | 1        |
# |    value_loss         | 6.67     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 83          |
# |    iterations         | 1400        |
# |    time_elapsed       | 83          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -37         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1399        |
# |    policy_loss        | 74.3        |
# |    reward             | -0.39913163 |
# |    std                | 1           |
# |    value_loss         | 4.97        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 84       |
# |    iterations         | 1500     |
# |    time_elapsed       | 89       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -37      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1499     |
# |    policy_loss        | 134      |
# |    reward             | 2.214675 |
# |    std                | 1        |
# |    value_loss         | 14.6     |
# ------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 84           |
# |    iterations         | 1600         |
# |    time_elapsed       | 95           |
# |    total_timesteps    | 8000         |
# | train/                |              |
# |    entropy_loss       | -37          |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0005       |
# |    n_updates          | 1599         |
# |    policy_loss        | -133         |
# |    reward             | -0.062391844 |
# |    std                | 1.01         |
# |    value_loss         | 17.9         |
# ----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 84       |
# |    iterations         | 1700     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -37      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1699     |
# |    policy_loss        | -45.8    |
# |    reward             | 1.757998 |
# |    std                | 1.01     |
# |    value_loss         | 4.97     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 84         |
# |    iterations         | 1800       |
# |    time_elapsed       | 106        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1799       |
# |    policy_loss        | 47.3       |
# |    reward             | -0.1251834 |
# |    std                | 1.01       |
# |    value_loss         | 3.89       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 84         |
# |    iterations         | 1900       |
# |    time_elapsed       | 112        |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1899       |
# |    policy_loss        | 59.4       |
# |    reward             | -1.9647285 |
# |    std                | 1.01       |
# |    value_loss         | 13.1       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 84        |
# |    iterations         | 2000      |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1999      |
# |    policy_loss        | 304       |
# |    reward             | -8.443542 |
# |    std                | 1         |
# |    value_loss         | 111       |
# -------------------------------------
# ======A2C Validation from:  2021-03-05 to  2021-06-04
# A2C Sharpe Ratio:  0.23900858522325624
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_14
# ------------------------------------
# | time/              |             |
# |    fps             | 87          |
# |    iterations      | 1           |
# |    time_elapsed    | 23          |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.15431233 |
# ------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 2           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017368611 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.9       |
# |    explained_variance   | -0.00777    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.02        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.02       |
# |    reward               | 2.1763704   |
# |    std                  | 1           |
# |    value_loss           | 8.32        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 3           |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016074643 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37         |
# |    explained_variance   | -0.0402     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0174     |
# |    reward               | 1.33739     |
# |    std                  | 1.01        |
# |    value_loss           | 19.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 4           |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012640566 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37         |
# |    explained_variance   | -0.00348    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 37.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0155     |
# |    reward               | 0.7388878   |
# |    std                  | 1.01        |
# |    value_loss           | 143         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 5           |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019385383 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.1       |
# |    explained_variance   | -0.0427     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.26        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0235     |
# |    reward               | -0.11048492 |
# |    std                  | 1.01        |
# |    value_loss           | 7.1         |
# -----------------------------------------
# ======PPO Validation from:  2021-03-05 to  2021-06-04
# PPO Sharpe Ratio:  0.1674232348374385
# ======TD3 Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/td3/td3_189_1
# day: 5829, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 7289129.23
# total_reward: 6289129.23
# total_cost: 3795.90
# total_trades: 86936
# Sharpe: 0.529
# =================================
# ======TD3 Validation from:  2021-03-05 to  2021-06-04
# ======Best Model Retraining from:  1998-01-01 to  2021-06-04
# ======Trading from:  2021-06-04 to  2021-09-02
# ============================================
# turbulence_threshold:  182.44639520957034
# ======Model training from:  1998-01-01 to  2021-06-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_252_13
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 100       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -36.9     |
# |    explained_variance | -0.0989   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 99        |
# |    policy_loss        | 16.6      |
# |    reward             | 0.8700964 |
# |    std                | 1         |
# |    value_loss         | 0.511     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 200       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -36.9     |
# |    explained_variance | 0.115     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 199       |
# |    policy_loss        | 3.09      |
# |    reward             | 1.0945117 |
# |    std                | 1         |
# |    value_loss         | 4.15      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 300        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -36.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 299        |
# |    policy_loss        | 12.8       |
# |    reward             | 0.11791113 |
# |    std                | 1          |
# |    value_loss         | 0.297      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 90        |
# |    iterations         | 400       |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -36.9     |
# |    explained_variance | -0.121    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 399       |
# |    policy_loss        | -27.8     |
# |    reward             | 0.6152955 |
# |    std                | 1         |
# |    value_loss         | 0.632     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 90         |
# |    iterations         | 500        |
# |    time_elapsed       | 27         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | 0.0802     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 499        |
# |    policy_loss        | -65.1      |
# |    reward             | -3.5065234 |
# |    std                | 1          |
# |    value_loss         | 5.13       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 600        |
# |    time_elapsed       | 33         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | -3.58e-07  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 599        |
# |    policy_loss        | -31.6      |
# |    reward             | 0.43531477 |
# |    std                | 1          |
# |    value_loss         | 1.8        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 700        |
# |    time_elapsed       | 39         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | -0.0847    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 699        |
# |    policy_loss        | -222       |
# |    reward             | 0.49328342 |
# |    std                | 1.01       |
# |    value_loss         | 40.4       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 800       |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 799       |
# |    policy_loss        | 59.8      |
# |    reward             | 1.7491254 |
# |    std                | 1         |
# |    value_loss         | 5.79      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 900       |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 899       |
# |    policy_loss        | -224      |
# |    reward             | 0.8011316 |
# |    std                | 1         |
# |    value_loss         | 40.6      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 1000      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | 0.0525    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 999       |
# |    policy_loss        | 51.6      |
# |    reward             | 1.7424994 |
# |    std                | 1         |
# |    value_loss         | 2.76      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 1100       |
# |    time_elapsed       | 61         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | -0.181     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1099       |
# |    policy_loss        | 51.1       |
# |    reward             | -2.0665975 |
# |    std                | 1          |
# |    value_loss         | 13.5       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 1200       |
# |    time_elapsed       | 67         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1199       |
# |    policy_loss        | -26.4      |
# |    reward             | 0.53925115 |
# |    std                | 1.01       |
# |    value_loss         | 0.721      |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 88       |
# |    iterations         | 1300     |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -37      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1299     |
# |    policy_loss        | -79.5    |
# |    reward             | 2.248191 |
# |    std                | 1.01     |
# |    value_loss         | 7.96     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 88          |
# |    iterations         | 1400        |
# |    time_elapsed       | 79          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -37.1       |
# |    explained_variance | 0.0138      |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1399        |
# |    policy_loss        | -19.8       |
# |    reward             | 0.029444491 |
# |    std                | 1.01        |
# |    value_loss         | 2           |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 1500      |
# |    time_elapsed       | 84        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | 0.0921    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1499      |
# |    policy_loss        | 24.4      |
# |    reward             | 1.1710933 |
# |    std                | 1.01      |
# |    value_loss         | 0.561     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 1600       |
# |    time_elapsed       | 90         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1599       |
# |    policy_loss        | -66.4      |
# |    reward             | 0.79993504 |
# |    std                | 1.01       |
# |    value_loss         | 3.82       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1700      |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.11     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1699      |
# |    policy_loss        | -62.3     |
# |    reward             | 1.0355062 |
# |    std                | 1.01      |
# |    value_loss         | 3.84      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1800       |
# |    time_elapsed       | 102        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0.0526     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1799       |
# |    policy_loss        | -67.3      |
# |    reward             | -0.4485697 |
# |    std                | 1.01       |
# |    value_loss         | 5.72       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1900       |
# |    time_elapsed       | 108        |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1899       |
# |    policy_loss        | 56.6       |
# |    reward             | -1.2610635 |
# |    std                | 1.01       |
# |    value_loss         | 2.73       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 2000      |
# |    time_elapsed       | 113       |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.0175   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1999      |
# |    policy_loss        | 74.8      |
# |    reward             | 0.8064706 |
# |    std                | 1.01      |
# |    value_loss         | 5.79      |
# -------------------------------------
# ======A2C Validation from:  2021-06-04 to  2021-09-02
# A2C Sharpe Ratio:  0.022684281880483607
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_252_13
# -----------------------------------
# | time/              |            |
# |    fps             | 90         |
# |    iterations      | 1          |
# |    time_elapsed    | 22         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.27139464 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 2           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 4096        |
# ...
# |    n_updates          | 199        |
# |    policy_loss        | 79.1       |
# |    reward             | 0.97550553 |
# |    std                | 1.01       |
# |    value_loss         | 5.13       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 84        |
# |    iterations         | 300       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | -0.101    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 299       |
# |    policy_loss        | 39.4      |
# |    reward             | 1.0703254 |
# |    std                | 1.01      |
# |    value_loss         | 2.12      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 84         |
# |    iterations         | 400        |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | -0.106     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 399        |
# |    policy_loss        | -74.7      |
# |    reward             | 0.53964007 |
# |    std                | 1.01       |
# |    value_loss         | 4.4        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 500        |
# |    time_elapsed       | 29         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -37        |
# |    explained_variance | -0.0104    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 499        |
# |    policy_loss        | 45.6       |
# |    reward             | -6.5892224 |
# |    std                | 1.01       |
# |    value_loss         | 10.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 600       |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -37       |
# |    explained_variance | 0.312     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 599       |
# |    policy_loss        | -112      |
# |    reward             | 0.7817249 |
# |    std                | 1.01      |
# |    value_loss         | 8.79      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 700        |
# |    time_elapsed       | 40         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 699        |
# |    policy_loss        | -530       |
# |    reward             | -1.9487996 |
# |    std                | 1.01       |
# |    value_loss         | 171        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 87       |
# |    iterations         | 800      |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -37.1    |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 799      |
# |    policy_loss        | -29.2    |
# |    reward             | 4.219984 |
# |    std                | 1.01     |
# |    value_loss         | 1.2      |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 900        |
# |    time_elapsed       | 51         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -37.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 899        |
# |    policy_loss        | -476       |
# |    reward             | -0.3045747 |
# |    std                | 1.01       |
# |    value_loss         | 174        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 1000      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 999       |
# |    policy_loss        | 219       |
# |    reward             | 2.2175434 |
# |    std                | 1.01      |
# |    value_loss         | 44.5      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 88          |
# |    iterations         | 1100        |
# |    time_elapsed       | 62          |
# |    total_timesteps    | 5500        |
# | train/                |             |
# |    entropy_loss       | -37.1       |
# |    explained_variance | 0.0105      |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1099        |
# |    policy_loss        | 335         |
# |    reward             | -0.37080222 |
# |    std                | 1.01        |
# |    value_loss         | 98.3        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 88          |
# |    iterations         | 1200        |
# |    time_elapsed       | 67          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -37.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1199        |
# |    policy_loss        | -1.23       |
# |    reward             | 0.013770195 |
# |    std                | 1.01        |
# |    value_loss         | 0.0118      |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 89        |
# |    iterations         | 1300      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -37.2     |
# |    explained_variance | -0.258    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1299      |
# |    policy_loss        | -121      |
# |    reward             | -0.316636 |
# |    std                | 1.01      |
# |    value_loss         | 23.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 1400      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -37.1     |
# |    explained_variance | -0.603    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1399      |
# |    policy_loss        | -14       |
# |    reward             | 2.5865703 |
# |    std                | 1.01      |
# |    value_loss         | 1.4       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 1500       |
# |    time_elapsed       | 84         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | -0.787     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1499       |
# |    policy_loss        | -3.28      |
# |    reward             | -0.3759082 |
# |    std                | 1.01       |
# |    value_loss         | 0.221      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1600       |
# |    time_elapsed       | 90         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -37.2      |
# |    explained_variance | -0.0132    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1599       |
# |    policy_loss        | 15.8       |
# |    reward             | 0.09655865 |
# |    std                | 1.01       |
# |    value_loss         | 0.473      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 1700       |
# |    time_elapsed       | 96         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -37.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1699       |
# |    policy_loss        | -114       |
# |    reward             | -2.3521543 |
# |    std                | 1.02       |
# |    value_loss         | 16.6       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 1800      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1799      |
# |    policy_loss        | 43.1      |
# |    reward             | 1.0318273 |
# |    std                | 1.02      |
# |    value_loss         | 2.93      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 88          |
# |    iterations         | 1900        |
# |    time_elapsed       | 107         |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -37.3       |
# |    explained_variance | 0.212       |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1899        |
# |    policy_loss        | 61.1        |
# |    reward             | -0.49807656 |
# |    std                | 1.02        |
# |    value_loss         | 3.81        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 2000      |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -37.3     |
# |    explained_variance | 0.281     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1999      |
# |    policy_loss        | -208      |
# |    reward             | 0.9848269 |
# |    std                | 1.02      |
# |    value_loss         | 32.7      |
# -------------------------------------
# ======A2C Validation from:  2021-09-02 to  2021-12-02
# A2C Sharpe Ratio:  -0.17408035090725163
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_315_11
# ------------------------------------
# | time/              |             |
# |    fps             | 88          |
# |    iterations      | 1           |
# |    time_elapsed    | 23          |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.27959117 |
# ------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 2           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016951323 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.9       |
# |    explained_variance   | -0.088      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.48        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.022      |
# |    reward               | 1.0916846   |
# |    std                  | 1           |
# |    value_loss           | 7.17        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 3           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014490535 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.9       |
# |    explained_variance   | -0.00923    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.23        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0146     |
# |    reward               | -0.96400774 |
# |    std                  | 1           |
# |    value_loss           | 23.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 4           |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.019543255 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.9       |
# |    explained_variance   | -0.0122     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 93.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00822    |
# |    reward               | 0.25130582  |
# |    std                  | 1           |
# |    value_loss           | 159         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 5           |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.021638447 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37         |
# |    explained_variance   | -0.0249     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.66        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0242     |
# |    reward               | 0.3147098   |
# |    std                  | 1.01        |
# |    value_loss           | 5.38        |
# -----------------------------------------
# ======PPO Validation from:  2021-09-02 to  2021-12-02
# PPO Sharpe Ratio:  -0.10489554992977053
# ======TD3 Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/td3/td3_315_1
# day: 5955, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 10322339.03
# total_reward: 9322339.03
# total_cost: 4087.89
# total_trades: 84645
# Sharpe: 0.591
# =================================
# ======TD3 Validation from:  2021-09-02 to  2021-12-02
# ======Best Model Retraining from:  1998-01-01 to  2021-12-02
# ======Trading from:  2021-12-02 to  2022-03-04
# Ensemble Strategy took:  34.661902368068695  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe TD3 Sharpe
# 0  126  2020-12-02  2021-03-05        PPO  -0.021037   0.069363  -0.052327
# 1  189  2021-03-05  2021-06-04        TD3   0.239009   0.167423   0.389611
# 2  252  2021-06-04  2021-09-02        TD3   0.022684  -0.056587   0.028146
# 3  315  2021-09-02  2021-12-02        PPO   -0.17408  -0.104896   -0.18402

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > val_test_start)&(processed.date <= val_test_end)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  0.5602609049888556

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2021-03-05           NaN  2021-03-05
# 1   1.000286e+06  2021-03-08      0.000286  2021-03-08
# 2   9.997878e+05  2021-03-09     -0.000498  2021-03-09
# 3   1.002605e+06  2021-03-10      0.002817  2021-03-10
# 4   1.004746e+06  2021-03-11      0.002135  2021-03-11

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.064721
# Cumulative returns     0.064721
# Annual volatility      0.126677
# Sharpe ratio           0.560261
# Calmar ratio           0.623404
# Stability              0.353930
# Max drawdown          -0.103819
# Omega ratio            1.099647
# Sortino ratio          0.794937
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.915375
# Daily value at risk   -0.015678
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.076357
# Cumulative returns     0.076042
# Annual volatility      0.128444
# Sharpe ratio           0.639265
# Calmar ratio           0.766080
# Stability              0.396026
# Max drawdown          -0.099672
# Omega ratio            1.110797
# Sortino ratio          0.907534
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.952372
# Daily value at risk   -0.015857
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-03-05</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-03-03</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>6.472%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>6.472%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>12.668%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.56</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.62</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.35</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-10.382%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.10</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.79</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.568%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.00</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.90</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10.38</td>
#       <td>2022-01-04</td>
#       <td>2022-02-23</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>7.14</td>
#       <td>2021-11-15</td>
#       <td>2021-12-01</td>
#       <td>2021-12-29</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.26</td>
#       <td>2021-07-26</td>
#       <td>2021-09-20</td>
#       <td>2021-11-03</td>
#       <td>73</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.82</td>
#       <td>2021-06-04</td>
#       <td>2021-06-18</td>
#       <td>2021-07-02</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.22</td>
#       <td>2021-05-10</td>
#       <td>2021-05-12</td>
#       <td>2021-06-02</td>
#       <td>18</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.03%</td>
#       <td>-3.42%</td>
#       <td>2.37%</td>
#     </tr>
#   </tbody>
# </table>
