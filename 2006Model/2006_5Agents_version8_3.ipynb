# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy - Modified: tech indicator
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# install finrl library
# !git clone https://github.com/AI4Finance-LLC/FinRL-Library.git

# %%
import sys
sys.path.append("FinRL-Library")

# %%
# install packages
# !pip install yfinance

# %%
# !pip install stockstats

# %%
#!pip install git+https://github.com/quantopian/pyfolio

# %%
# ## install finrl library
#!pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.apps import config
from finrl.finrl_meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.finrl_meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.finrl_meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.drl_agents.stablebaselines3.models_modified2 import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
# from config.py start_date is a string
# config.START_DATE

# %%
print(config.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
# I changed the end datae to yesterday, original date is 2021-07-06
df = YahooDownloader(start_date = '2006-01-01',
                     end_date = '2022-03-21',
                     ticker_list = config.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (118551, 8)

# %%
df.head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2006-01-03   2.585000   2.669643   2.580357   2.285946  807234400  AAPL
# 1  2006-01-03  79.360001  81.239998  78.099998  61.612606    9114400  AMGN
# 2  2006-01-03  51.700001  52.580002  51.049999  40.843647    7825700   AXP
# 3  2006-01-03  70.400002  70.599998  69.330002  50.119717    4943000    BA
# 4  2006-01-03  57.869999  58.110001  57.049999  37.493538    3697500   CAT
#
#    day
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
df.tail()
# Out:
#               date        open        high         low       close    volume  \
# 118546  2022-03-18  508.739990  510.679993  501.559998  506.119995   5059000
# 118547  2022-03-18  211.699997  219.259995  210.289993  219.110001  14608100
# 118548  2022-03-18   52.119999   52.290001   50.799999   50.799999  70348600
# 118549  2022-03-18   47.349998   47.450001   46.470001   47.360001  11368000
# 118550  2022-03-18  145.179993  145.570007  144.110001  145.440002  10407600
#
#         tic  day
# 118546  UNH    4
# 118547    V    4
# 118548   VZ    4
# 118549  WBA    4
# 118550  WMT    4

# %%
df.shape
# Out:
# (118551, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2006-01-03   2.585000   2.669643   2.580357   2.285946  807234400  AAPL
# 1  2006-01-03  79.360001  81.239998  78.099998  61.612606    9114400  AMGN
# 2  2006-01-03  51.700001  52.580002  51.049999  40.843647    7825700   AXP
# 3  2006-01-03  70.400002  70.599998  69.330002  50.119717    4943000    BA
# 4  2006-01-03  57.869999  58.110001  57.049999  37.493538    3697500   CAT
#
#    day
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
len(df.tic.unique())
# Out:
# 30

# %%
df.tic.value_counts()
# Out:
# AAPL    4081
# AMGN    4081
# WMT     4081
# WBA     4081
# VZ      4081
# UNH     4081
# TRV     4081
# PG      4081
# NKE     4081
# MSFT    4081
# MRK     4081
# MMM     4081
# MCD     4081
# KO      4081
# JPM     4081
# JNJ     4081
# INTC    4081
# IBM     4081
# HON     4081
# HD      4081
# GS      4081
# DIS     4081
# CVX     4081
# CSCO    4081
# CRM     4081
# CAT     4081
# BA      4081
# AXP     4081
# V       3526
# DOW      757
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
# added indicators
tech_indicators = [    "boll_ub", "boll_lb", # this two are new
'macd',
 'rsi_30',
 'cci_30',
 'dx_30']

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = tech_indicators,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.sample(5)
# Out:
#               date        open        high         low       close    volume  \
# 107284  2021-03-24   51.169998   51.889999   51.150002   49.978554  14997400
# 6497    2006-12-04   68.949997   69.500000   68.699997   53.017838  11247100
# 64216   2015-02-12  151.739960  152.485657  151.137665  110.405342   3486423
# 10402   2007-06-26   61.360001   61.959999   61.320000   39.954784  13908200
# 106902  2021-03-04   47.599998   48.090000   46.310001   45.113396   5252600
#
#          tic  day     boll_ub     boll_lb      macd     rsi_30      cci_30  \
# 107284    KO    2   50.497093   47.408404  0.387460  54.730803  141.002897
# 6497    AMGN    0   58.117184   53.299224 -0.673749  41.394556 -202.127494
# 64216    IBM    3  111.283298  104.704304  0.215581  49.720320   86.932249
# 10402    JNJ    1   41.416595   39.447597 -0.247069  45.480006 -113.592570
# 106902   WBA    3   48.840444   45.100245  0.080732  52.398551 -125.811842
#
#             dx_30  turbulence
# 107284  15.410568   20.336524
# 6497    47.501705    0.000000
# 64216    3.912671  257.392352
# 10402   24.088070   19.702086
# 106902   0.658507   17.245084

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(tech_indicators)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 28, State Space: 225

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": tech_indicators,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)
train_start = '2006-01-01'
train_end = '2020-12-01' #original is 2020-4-1
val_test_start = '2020-12-01' #original is 2020-4-1
val_test_end = '2022-03-21'#original is 2021-7-06

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(train_start,train_end),
                 val_test_period=(val_test_start,val_test_end),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.01,
                    'learning_rate': 0.0005
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 64
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 100_000,
                      "learning_rate": 0.000005,
                      "batch_size": 64
                    }

TD3_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 100_000,
                      "learning_rate": 0.000005,
                      "batch_size": 64
                    }

SAC_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 100_000,
                      "learning_rate": 0.000005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 30_000, 
                 'ppo' : 100_000, 
                 'ddpg' : 10_000,
                  'td3' : 30_000,
                  'sac' : 80_000
                 }


timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000,
                  'td3' : 10_000,
                  'sac' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                  TD3_model_kwargs,
                                                  SAC_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  202.91029981804178
# ======Model training from:  2006-01-01 to  2020-12-02
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_126_32
# --------------------------------------
# | time/                 |            |
# |    fps                | 30         |
# |    iterations         | 100        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 99         |
# |    policy_loss        | -28.7      |
# |    reward             | 0.13889919 |
# |    std                | 1          |
# |    value_loss         | 1.79       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 42        |
# |    iterations         | 200       |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -39.8     |
# |    explained_variance | 0.294     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 199       |
# |    policy_loss        | -5.3      |
# |    reward             | 0.6867177 |
# |    std                | 1         |
# |    value_loss         | 0.663     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 48        |
# |    iterations         | 300       |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -39.8     |
# |    explained_variance | 0.36      |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 299       |
# |    policy_loss        | 21.9      |
# |    reward             | 1.5582553 |
# |    std                | 1         |
# |    value_loss         | 1.54      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 52         |
# |    iterations         | 400        |
# |    time_elapsed       | 38         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | 0.211      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 399        |
# |    policy_loss        | -122       |
# |    reward             | -1.3833603 |
# |    std                | 1          |
# |    value_loss         | 11.4       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 55          |
# |    iterations         | 500         |
# |    time_elapsed       | 45          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | 0.0422      |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 499         |
# |    policy_loss        | 34.3        |
# |    reward             | 0.050005153 |
# |    std                | 1           |
# |    value_loss         | 1.49        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 57         |
# |    iterations         | 600        |
# |    time_elapsed       | 52         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | -0.0838    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 599        |
# |    policy_loss        | 55.3       |
# |    reward             | -1.9380574 |
# |    std                | 1          |
# |    value_loss         | 4.32       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 58         |
# |    iterations         | 700        |
# |    time_elapsed       | 59         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | -0.0264    |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 699        |
# |    policy_loss        | 257        |
# |    reward             | -3.5231085 |
# |    std                | 1          |
# |    value_loss         | 69.7       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 60          |
# |    iterations         | 800         |
# |    time_elapsed       | 66          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | -11.7       |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 799         |
# |    policy_loss        | -30.9       |
# |    reward             | -0.12678593 |
# |    std                | 1           |
# |    value_loss         | 0.671       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 61         |
# |    iterations         | 900        |
# |    time_elapsed       | 72         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | -0.62      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 899        |
# |    policy_loss        | 36.8       |
# |    reward             | -1.0427405 |
# |    std                | 1          |
# |    value_loss         | 4.34       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 62          |
# |    iterations         | 1000        |
# |    time_elapsed       | 79          |
# |    total_timesteps    | 5000        |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | 0.361       |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 999         |
# |    policy_loss        | 59.7        |
# |    reward             | -0.35006714 |
# |    std                | 1           |
# |    value_loss         | 3.98        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 63         |
# |    iterations         | 1100       |
# |    time_elapsed       | 86         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | -8.79      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1099       |
# |    policy_loss        | -36.5      |
# |    reward             | 0.50268084 |
# |    std                | 1          |
# |    value_loss         | 1.22       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 64         |
# |    iterations         | 1200       |
# |    time_elapsed       | 93         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | -0.13      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1199       |
# |    policy_loss        | -9.04      |
# |    reward             | 0.27975783 |
# |    std                | 1          |
# |    value_loss         | 0.732      |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 64            |
# |    iterations         | 1300          |
# |    time_elapsed       | 100           |
# |    total_timesteps    | 6500          |
# | train/                |               |
# |    entropy_loss       | -39.9         |
# |    explained_variance | -0.00812      |
# |    learning_rate      | 0.0005        |
# |    n_updates          | 1299          |
# |    policy_loss        | 78.5          |
# |    reward             | -0.0099931015 |
# |    std                | 1             |
# |    value_loss         | 5.08          |
# -----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 65        |
# |    iterations         | 1400      |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1399      |
# |    policy_loss        | -588      |
# |    reward             | 0.7311248 |
# |    std                | 1.01      |
# |    value_loss         | 331       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 65         |
# |    iterations         | 1500       |
# |    time_elapsed       | 113        |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1499       |
# |    policy_loss        | 250        |
# |    reward             | -3.3473315 |
# |    std                | 1          |
# |    value_loss         | 142        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 66        |
# |    iterations         | 1600      |
# |    time_elapsed       | 120       |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | -0.401    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1599      |
# |    policy_loss        | 90.2      |
# |    reward             | 0.4425459 |
# |    std                | 1.01      |
# |    value_loss         | 5.96      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 66         |
# |    iterations         | 1700       |
# |    time_elapsed       | 128        |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | -0.129     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1699       |
# |    policy_loss        | 0.446      |
# |    reward             | -1.2649556 |
# |    std                | 1.01       |
# |    value_loss         | 0.699      |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 66       |
# |    iterations         | 1800     |
# |    time_elapsed       | 135      |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -40      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1799     |
# |    policy_loss        | -193     |
# |    reward             | -0.97107 |
# |    std                | 1.01     |
# |    value_loss         | 25.2     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 66        |
# |    iterations         | 1900      |
# |    time_elapsed       | 142       |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | -0.0594   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1899      |
# |    policy_loss        | 52.8      |
# |    reward             | 0.9948227 |
# |    std                | 1.01      |
# |    value_loss         | 2.44      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 67         |
# |    iterations         | 2000       |
# |    time_elapsed       | 149        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | -9.78e-06  |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1999       |
# |    policy_loss        | -55.9      |
# |    reward             | -1.0722681 |
# |    std                | 1.01       |
# |    value_loss         | 10.1       |
# --------------------------------------
# ======A2C Validation from:  2020-12-02 to  2021-03-05
# A2C Sharpe Ratio:  -0.014874700884498531
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_30
# ----------------------------------
# | time/              |           |
# |    fps             | 73        |
# |    iterations      | 1         |
# |    time_elapsed    | 27        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.0537286 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 2           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.020050745 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.8       |
# |    explained_variance   | -0.00587    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.14        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0288     |
# |    reward               | 0.03241318  |
# |    std                  | 1           |
# |    value_loss           | 8.33        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 3           |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.019660141 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.8       |
# |    explained_variance   | 0.00303     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 25.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0244     |
# |    reward               | 1.7529062   |
# |    std                  | 1.01        |
# |    value_loss           | 59.9        |
# -----------------------------------------
# day: 3754, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 3965107.77
# total_reward: 2965107.77
# total_cost: 399952.13
# total_trades: 101003
# Sharpe: 0.566
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 4           |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.024664238 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.9       |
# |    explained_variance   | -0.053      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.61        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.026      |
# |    reward               | 4.648146    |
# |    std                  | 1.01        |
# |    value_loss           | 10.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 5           |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.02067513  |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -40         |
# |    explained_variance   | 0.0224      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.5         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0205     |
# |    reward               | -0.33497787 |
# |    std                  | 1.01        |
# |    value_loss           | 45.1        |
# -----------------------------------------
# ======PPO Validation from:  2020-12-02 to  2021-03-05
# PPO Sharpe Ratio:  -0.0757786883169456
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_126_24
# ======DDPG Validation from:  2020-12-02 to  2021-03-05
# ======TD3 Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/td3/td3_126_5
# ======TD3 Validation from:  2020-12-02 to  2021-03-05
# ======SAC Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/sac/sac_126_4
# day: 3754, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 5596794.68
# total_reward: 4596794.68
# total_cost: 8659.47
# total_trades: 49343
# Sharpe: 0.615
# =================================
# ======SAC Validation from:  2020-12-02 to  2021-03-05
# ======Best Model Retraining from:  2006-01-01 to  2021-03-05
# ======Trading from:  2021-03-05 to  2021-06-04
# ============================================
# turbulence_threshold:  202.91029981804178
# ======Model training from:  2006-01-01 to  2021-03-05
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_189_24
# --------------------------------------
# | time/                 |            |
# |    fps                | 76         |
# |    iterations         | 100        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 99         |
# |    policy_loss        | -37.3      |
# |    reward             | 0.06511829 |
# |    std                | 1          |
# |    value_loss         | 2.11       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 79        |
# |    iterations         | 200       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -39.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 199       |
# |    policy_loss        | 58.4      |
# |    reward             | 0.3750505 |
# |    std                | 1         |
# |    value_loss         | 4.56      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 80        |
# |    iterations         | 300       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -39.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 299       |
# |    policy_loss        | -34.9     |
# |    reward             | 1.5316781 |
# |    std                | 1         |
# |    value_loss         | 1.82      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 81        |
# |    iterations         | 400       |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -39.8     |
# |    explained_variance | -0.0773   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 399       |
# |    policy_loss        | -98.9     |
# |    reward             | -2.378265 |
# |    std                | 1         |
# |    value_loss         | 7.35      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 81         |
# |    iterations         | 500        |
# |    time_elapsed       | 30         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | 0.48       |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 499        |
# |    policy_loss        | 57.3       |
# |    reward             | -1.9463246 |
# |    std                | 1          |
# |    value_loss         | 2.2        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 81         |
# |    iterations         | 600        |
# |    time_elapsed       | 36         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | 0.0225     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 599        |
# |    policy_loss        | 54.9       |
# |    reward             | 0.78391826 |
# |    std                | 1          |
# |    value_loss         | 2.45       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 81         |
# |    iterations         | 700        |
# |    time_elapsed       | 42         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | 0.206      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 699        |
# |    policy_loss        | 22.3       |
# |    reward             | -0.3459196 |
# |    std                | 1          |
# |    value_loss         | 1.04       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 81          |
# |    iterations         | 800         |
# |    time_elapsed       | 48          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -39.9       |
# |    explained_variance | -0.237      |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 799         |
# |    policy_loss        | 26.3        |
# |    reward             | -0.27775526 |
# |    std                | 1           |
# |    value_loss         | 1.83        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 81          |
# |    iterations         | 900         |
# |    time_elapsed       | 54          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -39.9       |
# |    explained_variance | 0.242       |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 899         |
# |    policy_loss        | -34.2       |
# |    reward             | 0.029156337 |
# |    std                | 1           |
# |    value_loss         | 2.54        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 1000       |
# |    time_elapsed       | 60         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | -0.341     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 999        |
# |    policy_loss        | 81.9       |
# |    reward             | -0.6323295 |
# |    std                | 1          |
# |    value_loss         | 10.1       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 82        |
# |    iterations         | 1100      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -39.8     |
# |    explained_variance | 0.678     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1099      |
# |    policy_loss        | -1.32     |
# |    reward             | 1.9799162 |
# |    std                | 1         |
# |    value_loss         | 0.0406    |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 82          |
# |    iterations         | 1200        |
# |    time_elapsed       | 73          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -39.9       |
# |    explained_variance | -0.341      |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1199        |
# |    policy_loss        | 53.1        |
# |    reward             | -0.05425898 |
# |    std                | 1           |
# |    value_loss         | 2.06        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 1300       |
# |    time_elapsed       | 79         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | -2.31      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1299       |
# |    policy_loss        | -37.2      |
# |    reward             | 0.91532725 |
# |    std                | 1          |
# |    value_loss         | 1.34       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 1400       |
# |    time_elapsed       | 85         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | -0.00785   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1399       |
# |    policy_loss        | 41.5       |
# |    reward             | -0.2763685 |
# |    std                | 1          |
# |    value_loss         | 2.24       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 81         |
# |    iterations         | 1500       |
# |    time_elapsed       | 91         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | -0.219     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1499       |
# |    policy_loss        | 90.4       |
# |    reward             | -1.2208308 |
# |    std                | 1          |
# |    value_loss         | 6.25       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 1600       |
# |    time_elapsed       | 97         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | -0.00906   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1599       |
# |    policy_loss        | -51.6      |
# |    reward             | 0.75484926 |
# |    std                | 1          |
# |    value_loss         | 3.98       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 1700       |
# |    time_elapsed       | 102        |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | 0.11       |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1699       |
# |    policy_loss        | 77.6       |
# |    reward             | -0.6222658 |
# |    std                | 1          |
# |    value_loss         | 9.73       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 83         |
# |    iterations         | 1800       |
# |    time_elapsed       | 108        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | 0.153      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1799       |
# |    policy_loss        | -19.9      |
# |    reward             | -1.6724209 |
# |    std                | 1.01       |
# |    value_loss         | 2.42       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 83         |
# |    iterations         | 1900       |
# |    time_elapsed       | 113        |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | -0.633     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1899       |
# |    policy_loss        | -39        |
# |    reward             | -1.6705544 |
# |    std                | 1.01       |
# |    value_loss         | 3.58       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 84        |
# |    iterations         | 2000      |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1999      |
# |    policy_loss        | 77.7      |
# |    reward             | 1.4979511 |
# |    std                | 1.01      |
# |    value_loss         | 7.52      |
# -------------------------------------
# ======A2C Validation from:  2021-03-05 to  2021-06-04
# A2C Sharpe Ratio:  0.3128912695068645
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_24
# ----------------------------------
# | time/              |           |
# |    fps             | 96        |
# |    iterations      | 1         |
# |    time_elapsed    | 21        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.1619222 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 2           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.020815644 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.8       |
# |    explained_variance   | -0.0108     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.42        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0288     |
# |    reward               | -0.7344409  |
# |    std                  | 1           |
# |    value_loss           | 8.47        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 3           |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017406533 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.9       |
# |    explained_variance   | -0.01       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0165     |
# |    reward               | -1.0552125  |
# |    std                  | 1.01        |
# |    value_loss           | 55.7        |
# -----------------------------------------
# day: 3817, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 2540289.43
# total_reward: 1540289.43
# total_cost: 403056.93
# total_trades: 101235
# Sharpe: 0.412
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 4           |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.022867383 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.9       |
# |    explained_variance   | -0.0228     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.59        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0238     |
# |    reward               | 2.4666455   |
# |    std                  | 1.01        |
# |    value_loss           | 9.07        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 5           |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.023415904 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -40         |
# |    explained_variance   | 0.00196     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.97        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0185     |
# |    reward               | -0.22923255 |
# |    std                  | 1.01        |
# |    value_loss           | 22.3        |
# -----------------------------------------
# ======PPO Validation from:  2021-03-05 to  2021-06-04
# PPO Sharpe Ratio:  0.3406587910951901
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_189_23
# ======DDPG Validation from:  2021-03-05 to  2021-06-04
# ======TD3 Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/td3/td3_189_5
# ======TD3 Validation from:  2021-03-05 to  2021-06-04
# ======SAC Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/sac/sac_189_4
# day: 3817, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 5460126.95
# total_reward: 4460126.95
# total_cost: 6376.99
# total_trades: 66402
# Sharpe: 0.536
# =================================
# ======SAC Validation from:  2021-03-05 to  2021-06-04
# ======Best Model Retraining from:  2006-01-01 to  2021-06-04
# ======Trading from:  2021-06-04 to  2021-09-02
# ============================================
# turbulence_threshold:  202.91029981804178
# ======Model training from:  2006-01-01 to  2021-06-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_252_23
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 100        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | -0.371     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 99         |
# |    policy_loss        | -23.4      |
# |    reward             | 0.16036029 |
# |    std                | 1.01       |
# |    value_loss         | 1.76       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 200        |
# |    time_elapsed       | 10         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | -0.147     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 199        |
# |    policy_loss        | 56.8       |
# |    reward             | 0.53983486 |
# |    std                | 1.01       |
# |    value_loss         | 3.87       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 300       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -40       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 299       |
# |    policy_loss        | -51.5     |
# |    reward             | 1.1267382 |
# |    std                | 1.01      |
# |    value_loss         | 2.1       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 400        |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 399        |
# |    policy_loss        | -79.6      |
# |    reward             | -2.2237265 |
# |    std                | 1.01       |
# |    value_loss         | 4.27       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 500       |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -40       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 499       |
# |    policy_loss        | 249       |
# |    reward             | -0.290324 |
# |    std                | 1.01      |
# |    value_loss         | 35.6      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 600       |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -40       |
# |    explained_variance | -0.0156   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 599       |
# |    policy_loss        | 84.9      |
# |    reward             | -1.212115 |
# |    std                | 1.01      |
# |    value_loss         | 10.5      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 101        |
# |    iterations         | 700        |
# |    time_elapsed       | 34         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 699        |
# |    policy_loss        | 474        |
# |    reward             | -0.0705839 |
# |    std                | 1.01       |
# |    value_loss         | 300        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 101         |
# |    iterations         | 800         |
# |    time_elapsed       | 39          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -39.9       |
# |    explained_variance | 0.0377      |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 799         |
# |    policy_loss        | 41.3        |
# |    reward             | -0.36722362 |
# |    std                | 1.01        |
# |    value_loss         | 1.51        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 101        |
# |    iterations         | 900        |
# |    time_elapsed       | 44         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | -0.00176   |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 899        |
# |    policy_loss        | -8.64      |
# |    reward             | 0.52749944 |
# |    std                | 1.01       |
# |    value_loss         | 1.55       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 1000      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -40       |
# |    explained_variance | -0.00157  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 999       |
# |    policy_loss        | -53.9     |
# |    reward             | 2.3773577 |
# |    std                | 1.01      |
# |    value_loss         | 4.3       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 101        |
# |    iterations         | 1100       |
# |    time_elapsed       | 54         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | -0.043     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1099       |
# |    policy_loss        | -19.4      |
# |    reward             | 0.24873348 |
# |    std                | 1.01       |
# |    value_loss         | 0.426      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 1200      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -40       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1199      |
# |    policy_loss        | 25.9      |
# |    reward             | 1.9730649 |
# |    std                | 1.01      |
# |    value_loss         | 0.432     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 1300     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -40      |
# |    explained_variance | 0.123    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1299     |
# |    policy_loss        | -83      |
# |    reward             | 1.394995 |
# |    std                | 1.01     |
# |    value_loss         | 5.96     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 101        |
# |    iterations         | 1400       |
# |    time_elapsed       | 69         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1399       |
# |    policy_loss        | -118       |
# |    reward             | -1.2116916 |
# |    std                | 1.01       |
# |    value_loss         | 10.1       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 1500      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1499      |
# |    policy_loss        | -475      |
# |    reward             | 7.5929937 |
# |    std                | 1.01      |
# |    value_loss         | 161       |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 101         |
# |    iterations         | 1600        |
# |    time_elapsed       | 78          |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -39.9       |
# |    explained_variance | -0.0112     |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1599        |
# |    policy_loss        | 25.2        |
# |    reward             | -0.34351066 |
# |    std                | 1.01        |
# |    value_loss         | 0.584       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 1700      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -40       |
# |    explained_variance | -0.31     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1699      |
# |    policy_loss        | -106      |
# |    reward             | 1.9458249 |
# |    std                | 1.01      |
# |    value_loss         | 13.1      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 1800      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -40       |
# |    explained_variance | -0.000499 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1799      |
# |    policy_loss        | -21.2     |
# |    reward             | 1.6572366 |
# |    std                | 1.01      |
# |    value_loss         | 0.747     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 1900      |
# |    time_elapsed       | 93        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -40       |
# |    explained_variance | 0.36      |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1899      |
# |    policy_loss        | 43.2      |
# |    reward             | 1.5349818 |
# |    std                | 1.01      |
# |    value_loss         | 2.69      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 2000      |
# ...
# |    explained_variance | -0.023    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 299       |
# |    policy_loss        | -48.2     |
# |    reward             | 1.1342329 |
# |    std                | 1         |
# |    value_loss         | 1.47      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 400        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | 0.243      |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 399        |
# |    policy_loss        | -81.6      |
# |    reward             | -1.3804476 |
# |    std                | 1.01       |
# |    value_loss         | 4.98       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 99        |
# |    iterations         | 500       |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | -0.283    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 499       |
# |    policy_loss        | 54        |
# |    reward             | -2.265742 |
# |    std                | 1.01      |
# |    value_loss         | 2.07      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 600        |
# |    time_elapsed       | 30         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | 0.18       |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 599        |
# |    policy_loss        | 84.1       |
# |    reward             | 0.24764267 |
# |    std                | 1.01       |
# |    value_loss         | 6.33       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 700        |
# |    time_elapsed       | 35         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 699        |
# |    policy_loss        | -100       |
# |    reward             | 0.42665565 |
# |    std                | 1          |
# |    value_loss         | 7.06       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 99          |
# |    iterations         | 800         |
# |    time_elapsed       | 40          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -39.9       |
# |    explained_variance | -0.4        |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 799         |
# |    policy_loss        | 59.7        |
# |    reward             | -0.06486448 |
# |    std                | 1.01        |
# |    value_loss         | 2.62        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 900        |
# |    time_elapsed       | 45         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | 0.0161     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 899        |
# |    policy_loss        | 147        |
# |    reward             | 0.96267164 |
# |    std                | 1.01       |
# |    value_loss         | 17.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 1000      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | -0.737    |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 999       |
# |    policy_loss        | 58.1      |
# |    reward             | 0.3712692 |
# |    std                | 1.01      |
# |    value_loss         | 2.5       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 1100      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1099      |
# |    policy_loss        | -72.3     |
# |    reward             | 1.5298439 |
# |    std                | 1.01      |
# |    value_loss         | 3.6       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 1200      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | 0.000344  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1199      |
# |    policy_loss        | -19.8     |
# |    reward             | 1.4918354 |
# |    std                | 1.01      |
# |    value_loss         | 0.509     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 1300      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1299      |
# |    policy_loss        | -82.9     |
# |    reward             | 3.9858785 |
# |    std                | 1.01      |
# |    value_loss         | 5.57      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 1400      |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1399      |
# |    policy_loss        | 479       |
# |    reward             | 6.2449045 |
# |    std                | 1.01      |
# |    value_loss         | 175       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 1500      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1499      |
# |    policy_loss        | 346       |
# |    reward             | -2.263921 |
# |    std                | 1.01      |
# |    value_loss         | 83.8      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 1600      |
# |    time_elapsed       | 79        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -40       |
# |    explained_variance | 0.057     |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1599      |
# |    policy_loss        | -49.5     |
# |    reward             | 1.3959333 |
# |    std                | 1.01      |
# |    value_loss         | 2.56      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 100         |
# |    iterations         | 1700        |
# |    time_elapsed       | 84          |
# |    total_timesteps    | 8500        |
# | train/                |             |
# |    entropy_loss       | -40         |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0005      |
# |    n_updates          | 1699        |
# |    policy_loss        | -58.7       |
# |    reward             | -0.44766235 |
# |    std                | 1.01        |
# |    value_loss         | 2.42        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 1800       |
# |    time_elapsed       | 89         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | 0.0154     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1799       |
# |    policy_loss        | 107        |
# |    reward             | -3.8040924 |
# |    std                | 1.01       |
# |    value_loss         | 8.04       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 1900      |
# |    time_elapsed       | 94        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -39.9     |
# |    explained_variance | -0.0691   |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1899      |
# |    policy_loss        | 17.9      |
# |    reward             | 1.2519405 |
# |    std                | 1.01      |
# |    value_loss         | 4.46      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 2000       |
# |    time_elapsed       | 99         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | -0.374     |
# |    learning_rate      | 0.0005     |
# |    n_updates          | 1999       |
# |    policy_loss        | -56.7      |
# |    reward             | 0.16907898 |
# |    std                | 1.01       |
# |    value_loss         | 3.06       |
# --------------------------------------
# ======A2C Validation from:  2021-09-02 to  2021-12-02
# A2C Sharpe Ratio:  0.06472709955660456
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_315_21
# ----------------------------------
# | time/              |           |
# |    fps             | 105       |
# |    iterations      | 1         |
# |    time_elapsed    | 19        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.3064066 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 2           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.022030277 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.8       |
# |    explained_variance   | -0.0168     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4           |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0284     |
# |    reward               | 0.08332094  |
# |    std                  | 1           |
# |    value_loss           | 7.4         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 3           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014564152 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.8       |
# |    explained_variance   | -0.000214   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 18.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0175     |
# |    reward               | -0.64654034 |
# |    std                  | 1           |
# |    value_loss           | 78.8        |
# -----------------------------------------
# day: 3943, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 2866907.61
# total_reward: 1866907.61
# total_cost: 430606.87
# total_trades: 104743
# Sharpe: 0.443
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 4           |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.019604515 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.9       |
# |    explained_variance   | -0.0401     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.94        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0264     |
# |    reward               | 1.7457643   |
# |    std                  | 1.01        |
# |    value_loss           | 5.98        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 5           |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.023362815 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.9       |
# |    explained_variance   | -0.0016     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.4        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0229     |
# |    reward               | 2.4142988   |
# |    std                  | 1.01        |
# |    value_loss           | 53          |
# -----------------------------------------
# ======PPO Validation from:  2021-09-02 to  2021-12-02
# PPO Sharpe Ratio:  -0.18225496698527807
# ======DDPG Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_315_19
# ======DDPG Validation from:  2021-09-02 to  2021-12-02
# ======TD3 Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/td3/td3_315_5
# ======TD3 Validation from:  2021-09-02 to  2021-12-02
# ======SAC Training========
# {'buffer_size': 100000, 'learning_rate': 5e-06, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/sac/sac_315_4
# day: 3943, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 5644671.67
# total_reward: 4644671.67
# total_cost: 11699.25
# total_trades: 55088
# Sharpe: 0.585
# =================================
# ======SAC Validation from:  2021-09-02 to  2021-12-02
# ======Best Model Retraining from:  2006-01-01 to  2021-12-02
# ======Trading from:  2021-12-02 to  2022-03-04
# Ensemble Strategy took:  64.37966115077337  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe  \
# 0  126  2020-12-02  2021-03-05        TD3  -0.014875  -0.075779      0.0129
# 1  189  2021-03-05  2021-06-04       DDPG   0.312891   0.340659    0.441699
# 2  252  2021-06-04  2021-09-02        A2C   0.280257  -0.018647    0.123625
# 3  315  2021-09-02  2021-12-02        TD3   0.064727  -0.182255   -0.004568
#
#   TD3 Sharpe SAC Sharpe
# 0   0.197276  -0.036497
# 1   0.224857   0.373029
# 2  -0.005021   0.177585
# 3   0.093408  -0.055184

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > val_test_start)&(processed.date <= val_test_end)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  0.3566493315431038

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2021-03-05           NaN  2021-03-05
# 1   1.002465e+06  2021-03-08      0.002465  2021-03-08
# 2   1.002364e+06  2021-03-09     -0.000100  2021-03-09
# 3   1.013242e+06  2021-03-10      0.010852  2021-03-10
# 4   1.019129e+06  2021-03-11      0.005811  2021-03-11

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.041028
# Cumulative returns     0.041028
# Annual volatility      0.141042
# Sharpe ratio           0.356649
# Calmar ratio           0.267795
# Stability              0.465097
# Max drawdown          -0.153208
# Omega ratio            1.059701
# Sortino ratio          0.491356
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.932590
# Daily value at risk   -0.017570
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.076357
# Cumulative returns     0.076042
# Annual volatility      0.128444
# Sharpe ratio           0.639265
# Calmar ratio           0.766080
# Stability              0.396026
# Max drawdown          -0.099672
# Omega ratio            1.110797
# Sortino ratio          0.907534
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.952372
# Daily value at risk   -0.015857
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-03-05</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-03-03</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>4.103%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>4.103%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>14.104%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.36</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.27</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.47</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-15.321%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.06</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.49</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.757%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.02</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.92</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>15.32</td>
#       <td>2021-12-31</td>
#       <td>2022-02-23</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6.03</td>
#       <td>2021-05-10</td>
#       <td>2021-06-18</td>
#       <td>2021-07-23</td>
#       <td>55</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.69</td>
#       <td>2021-08-16</td>
#       <td>2021-09-30</td>
#       <td>2021-10-19</td>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.60</td>
#       <td>2021-12-10</td>
#       <td>2021-12-20</td>
#       <td>2021-12-28</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.48</td>
#       <td>2021-11-24</td>
#       <td>2021-12-01</td>
#       <td>2021-12-10</td>
#       <td>13</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.02%</td>
#       <td>-3.68%</td>
#       <td>2.42%</td>
#     </tr>
#   </tbody>
# </table>
